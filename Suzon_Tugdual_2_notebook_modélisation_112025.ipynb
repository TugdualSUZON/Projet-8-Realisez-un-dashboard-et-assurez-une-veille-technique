# %% [markdown]
# # Partie I : Feature engineering à partir d'un proposition Kaggel
# [Lien vers le Kaggel](https://www.kaggle.com/code/jsaguiar/lightgbm-with-simple-features/script)

# %% [markdown]
# ## 1. Initialisation

# %% [markdown]
# ### 1.1 Packages

# %%
import os
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborne as sns

# %% [markdown]
# ### 1.2 Fonctions

# %% [markdown]
# Preprocess fonctions issue de Kaggel

# %%
# HOME CREDIT DEFAULT RISK COMPETITION
# Most features are created by applying min, max, mean, sum and var functions to grouped tables. 
# Little feature selection is done and overfitting might be a problem since many features are related.
# The following key ideas were used:
# - Divide or subtract important features to get rates (like annuity and income)
# - In Bureau Data: create specific features for Active credits and Closed credits
# - In Previous Applications: create specific features for Approved and Refused applications
# - Modularity: one function for each table (except bureau_balance and application_test)
# - One-hot encoding for categorical features
# All tables are joined with the application DF using the SK_ID_CURR key (except bureau_balance).
# You can use LightGBM with KFold or Stratified KFold.

# Update 16/06/2018:
# - Added Payment Rate feature
# - Removed index from features
# - Use standard KFold CV (not stratified)

import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
# from lightgbm import LGBMClassifier
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# One-hot encoding for categorical columns with get_dummies
def categorie_feature_encoder(df, nan_as_category = False):
    
    # Get the object type columns
    object_columns = df.select_dtypes("object").columns
    
    ## Count class in each columns and isolate the one with stricly less than three class
    tow_class_columns = []
    more_class_columns = []

    for column in object_columns:
        n_class = len(
                    df[column].unique()
                    )
        
        if n_class < 3:
            tow_class_columns.append(column)
            
        elif n_class >= 2 :
            more_class_columns.append(column)
    if nan_as_category:    
        ordinal_encoder = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=42)
        one_hot_encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
        
    else:
        ordinal_encoder = OrdinalEncoder()
        one_hot_encoder = OneHotEncoder(sparse_output=False)

    # For the exactly tow categories
    df_index = df[tow_class_columns].index
    ordinal_encoded = ordinal_encoder.fit_transform(df[tow_class_columns])
    tow_class_columns_encoded = ordinal_encoder.get_feature_names_out()
    ordinal_encoded = pd.DataFrame(ordinal_encoded, columns = tow_class_columns_encoded, index=df_index)
    
    
    # For the more than tow catégories
    df_index = df[more_class_columns].index
    one_hot_encoded = one_hot_encoder.fit_transform(df[more_class_columns])
    more_class_columns_encoded = one_hot_encoder.get_feature_names_out()
    one_hot_encoded = pd.DataFrame(one_hot_encoded, columns = more_class_columns_encoded, index=df_index)
    
    # Remove the orignal columns
    df_out = df.drop(object_columns, axis=1)
    del df
    
    # Add the new
    df_out = pd.concat([df_out, ordinal_encoded], axis=1)
    df_out = pd.concat([df_out, one_hot_encoded], axis=1)

    # Recover he new columns names
    new_columns = np.append(tow_class_columns_encoded, more_class_columns_encoded)
    
    return df_out, new_columns

# Preprocess application_train.csv and application_test.csv
def application_train_test(data_directory, num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv(f'{data_directory}/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv(f'{data_directory}/application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = pd.concat([df, test_df], axis=0, ignore_index=True)

    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    drop_index = df.loc[df["CODE_GENDER"] == "XNA"].index
    df = df.drop(drop_index)
    del drop_index
    
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = categorie_feature_encoder(df, nan_as_category)
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    # Create an annomalie flag column 
    df['DAYS_EMPLOYED_ANOM'] = 0
    mask = df["DAYS_EMPLOYED"] == 365243
    df.loc[mask, "DAYS_EMPLOYED_ANOM"] = 1
    # Change value
    df.loc[mask, "DAYS_EMPLOYED"] = np.nan
    
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    del test_df
    gc.collect()
    return df

# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(data_directory, num_rows = None, nan_as_category = True):
    bureau = pd.read_csv(f'{data_directory}/bureau.csv', nrows = num_rows)
    bb = pd.read_csv(f'{data_directory}/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = categorie_feature_encoder(bb, nan_as_category)
    bureau, bureau_cat = categorie_feature_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
    
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# Preprocess previous_applications.csv
def previous_applications(data_directory, num_rows = None, nan_as_category = True):
    prev = pd.read_csv(f'{data_directory}/previous_application.csv', nrows = num_rows)
    prev, cat_cols = categorie_feature_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# Preprocess POS_CASH_balance.csv
def pos_cash(data_directory, num_rows = None, nan_as_category = True):
    pos = pd.read_csv(f'{data_directory}/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = categorie_feature_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg
    
# Preprocess installments_payments.csv
def installments_payments(data_directory, num_rows = None, nan_as_category = True):
    ins = pd.read_csv(f'{data_directory}/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = categorie_feature_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# Preprocess credit_card_balance.csv
def credit_card_balance(data_directory, num_rows = None, nan_as_category = True):
    cc = pd.read_csv(f'{data_directory}/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = categorie_feature_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

def main(data_directory, debug = False):
    '''
    Appliquer les différentes transformation précédente sur les données de l'étude.

    Return :
        df (dataframe) : dataframe qui contient le résultat des la combinaison et du feature engineering réaliser sur les données. 
    '''
    num_rows = 10000 if debug else None
    df = application_train_test(data_directory, num_rows)
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(data_directory, num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')
        del bureau
        gc.collect()
    with timer("Process previous_applications"):
        prev = previous_applications(data_directory, num_rows)
        print("Previous applications df shape:", prev.shape)
        df = df.join(prev, how='left', on='SK_ID_CURR')
        del prev
        gc.collect()
    with timer("Process POS-CASH balance"):
        pos = pos_cash(data_directory, num_rows)
        print("Pos-cash balance df shape:", pos.shape)
        df = df.join(pos, how='left', on='SK_ID_CURR')
        del pos
        gc.collect()
    with timer("Process installments payments"):
        ins = installments_payments(data_directory, num_rows)
        print("Installments payments df shape:", ins.shape)
        df = df.join(ins, how='left', on='SK_ID_CURR')
        del ins
        gc.collect()
    with timer("Process credit card balance"):
        cc = credit_card_balance(data_directory, num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
        del cc
        gc.collect()
        
    return df

# %% [markdown]
# ## 2. Importation/transformation avec les fonctions de Kaggel

# %%
data_directory = r"./data/raw"
data = main(data_directory, debug=False)
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 112)
# Process bureau and bureau_balance - done in 25s
# Previous applications df shape: (338857, 234)
# Process previous_applications - done in 24s
# Pos-cash balance df shape: (337252, 17)
# Process POS-CASH balance - done in 12s
# Installments payments df shape: (339587, 26)
# Process installments payments - done in 21s
# Credit card balance df shape: (103558, 136)
# Process credit card balance - done in 15s

# %%
data.shape
# Out:
# (356251, 778)

# %% [markdown]
# ## 3. Exportation
# Sauvegarder le résultats pour ne pas le recalculer à chaque entraînement

# %% [markdown]
# ### 3.1 Retirer les erreurs d'infini produit par la méthode

# %%
# Vérifier la présence de valeurs infinis
data.isin([np.inf, -np.inf]).any().value_counts()
# Out:
# False    771
# True       7
# Name: count, dtype: int64

# %%
# Identifier les colonnes

# %%
inf_column = data.columns[data.isin([np.inf, -np.inf]).any() ]

# %%
# Identifier les lignes
drop_index = np.array([])
for column in inf_column :
    index = data.loc[data[column].isin([np.inf, -np.inf]), column].index
    print(index)
    
    index = np.array(index)
    drop_index = np.append(drop_index, index)

drop_index = np.unique(drop_index)
# Out:
# Index([201086], dtype='int64')
# Index([201086], dtype='int64')
# Index([201086], dtype='int64')
# Index([201086], dtype='int64')
# Index([  5687,  60477,  79077,  89018,  98509, 126768, 128791, 140426, 152087,
#        167136, 199103, 236164, 238381, 272829, 277962, 287300, 292852, 305373,
#        310339],
#       dtype='int64')
# Index([  5687,  60477,  79077,  89018,  98509, 126768, 128791, 140426, 152087,
#        167136, 199103, 236164, 238381, 272829, 277962, 287300, 292852, 305373,
#        310339],
#       dtype='int64')
# Index([  5687,  60477,  79077,  89018,  98509, 126768, 128791, 140426, 152087,
#        167136, 199103, 236164, 238381, 272829, 277962, 287300, 292852, 305373,
#        310339],
#       dtype='int64')

# %%
print(f"{len(drop_index)} lignes contiennent des valeurs inf")
# Out:
# 20 lignes contiennent des valeurs inf

# %% [markdown]
# On vire toutes les lignes qui contiennent ces valeurs. Pourrai aussi les rendre null

# %%
data = data.drop(drop_index)
# Vérifier la présence d'infinis
data.isin([np.inf, -np.inf]).any().value_counts()
# Out:
# False    778
# Name: count, dtype: int64

# %%
del drop_index

# %% [markdown]
# ### 3.2 Sauvegarde des résultats

# %%
out_directory = r"./data/transformed"

# %%
data.to_csv(os.path.join(out_directory,"train_data_V1.csv"), header=True, index=False)

# %% [markdown]
# ### 3.3 Export d'un exemple d'une ligne

# %%
temp = data.loc[data["SK_ID_CURR"] == 281026, :]

# %%
temp.to_csv(os.path.join(out_directory, "test_dashboard_V1.csv"),
           index=False)

# %% [markdown]
# ## 4. Nettoyer les variables

# %%
# %reset -f

# %% [markdown]
# # Partie II : Entraînement du modèle suivi avec MlFlow

# %% [markdown]
# ## 1. Initialisation

# %% [markdown]
# ### 1.1 Package

# %%
import os
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
# Construction des dataset
from sklearn.model_selection import train_test_split

# %%
# Pipeline

##from sklearn.pipeline import Pipeline

# Pour utiliser SMOTE dans un pipeline il faut prendre l'outil pipe de sk imbalance learn
from imblearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV # Recherche d'hyperparamètres
from sklearn.model_selection import TunedThresholdClassifierCV # optimisation du seuil de décision
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
# Définition d'une métric
from sklearn.metrics import confusion_matrix, make_scorer, precision_score, recall_score

# %%
# Réduction de dimension
from sklearn.decomposition import PCA

# %%
# Synthetic Minority Oversampling Technique SMOTE
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
# Modèles
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
# MlFlow
import mlflow
import mlflow.sklearn
from mlflow import MlflowClient
from mlflow.models.signature import infer_signature

# %% [markdown]
# ### 1.2 Fonction

# %% [markdown]
# Tracer les graphiques

# %%
def plot_roc_pr_curves(vanilla_model, tuned_model, *, title):
    fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(21, 6))

    linestyles = ("dashed", "dotted")
    markerstyles = ("o", ">")
    colors = ("tab:blue", "tab:orange")
    names = ("Vanilla GBDT", "Tuned GBDT")
    for idx, (est, linestyle, marker, color, name) in enumerate(
        zip((vanilla_model, tuned_model), linestyles, markerstyles, colors, names)
    ):
        decision_threshold = getattr(est, "best_threshold_", 0.5)
        PrecisionRecallDisplay.from_estimator(
            est,
            X_test,
            y_test,
            pos_label=pos_label,
            linestyle=linestyle,
            color=color,
            ax=axs[0],
            name=name,
        )
        axs[0].plot(
            scoring["recall"](est, X_test, y_test),
            scoring["precision"](est, X_test, y_test),
            marker,
            markersize=10,
            color=color,
            label=f"Cut-off point at probability of {decision_threshold:.2f}",
        )
        RocCurveDisplay.from_estimator(
            est,
            X_test,
            y_test,
            pos_label=pos_label,
            curve_kwargs=dict(linestyle=linestyle, color=color),
            ax=axs[1],
            name=name,
            plot_chance_level=idx == 1,
        )
        axs[1].plot(
            scoring["fpr"](est, X_test, y_test),
            scoring["tpr"](est, X_test, y_test),
            marker,
            markersize=10,
            color=color,
            label=f"Cut-off point at probability of {decision_threshold:.2f}",
        )

    axs[0].set_title("Precision-Recall curve")
    axs[0].legend()
    axs[1].set_title("ROC curve")
    axs[1].legend()

    axs[2].plot(
        tuned_model.cv_results_["thresholds"],
        tuned_model.cv_results_["scores"],
        color="tab:orange",
    )
    axs[2].plot(
        tuned_model.best_threshold_,
        tuned_model.best_score_,
        "o",
        markersize=10,
        color="tab:orange",
        label="Optimal cut-off point for the business metric",
    )
    axs[2].legend()
    axs[2].set_xlabel("Decision threshold (probability)")
    axs[2].set_ylabel("Objective score (using cost-matrix)")
    axs[2].set_title("Objective score as a function of the decision threshold")
    fig.suptitle(title)

    plt.show()

# %% [markdown]
# ## 2. Données

# %% [markdown]
# ### 2.1 Importation

# %% [markdown]
# Chemins des dossiers

# %%
input_directory = r"./data/transformed/"
out_directory = r"./data/modeles/"

# %% [markdown]
# Noms des fichiers

# %%
os.listdir(input_directory)
# Out:
# ['test_dashboard_V1.csv', 'train_data_V0.csv', 'train_data_V1.csv']

# %%
raw = pd.read_csv(os.path.join(input_directory, "train_data_V1.csv"))
print(raw.shape)
raw.head()
# Out:
# (356231, 778)
#    SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      100002     1.0            0             0                0
# 1      100003     0.0            1             0                1
# 2      100004     0.0            0             1                0
# 3      100006     0.0            1             0                0
# 4      100007     0.0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          202500.0    406597.5      24700.5         351000.0
# 1             0          270000.0   1293502.5      35698.5        1129500.0
# 2             0           67500.0    135000.0       6750.0         135000.0
# 3             0          135000.0    312682.5      29686.5         297000.0
# 4             0          121500.0    513000.0      21865.5         513000.0
#
#    ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0  ...                                        NaN
# 1  ...                                        NaN
# 2  ...                                        NaN
# 3  ...                                        0.0
# 4  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         0.0
# 4                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        0.0
# 4                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        0.0
# 4                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 0.0                                 0.0
# 4                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  0.0                                 0.0
# 4                                  NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_COUNT
# 0                                 NaN       NaN
# 1                                 NaN       NaN
# 2                                 NaN       NaN
# 3                                 0.0       6.0
# 4                                 NaN       NaN
#
# [5 rows x 778 columns]

# %%
# Vérifier la présence d'infinis
raw.isin([np.inf, -np.inf]).any().value_counts()
# Out:
# False    778
# Name: count, dtype: int64

# %% [markdown]
# Isoler le dataset d'entrainenemnt de celui de test

# %%
# Test
data_test = raw.loc[raw["TARGET"].isna(), :]
print(data_test.shape)
display(data_test.head(2))

# Entraînement
data = raw.loc[~raw["TARGET"].isna(), :]
print(data.shape)
display(data.head(2))
# Out:
# (48743, 778)
#         SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 307488      100001     NaN            1             0                0
# 307489      100005     NaN            0             0                0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 307488             0          135000.0    568800.0      20560.5
# 307489             0           99000.0    222768.0      17370.0
#
#         AMT_GOODS_PRICE  ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 307488         450000.0  ...                                        NaN
# 307489         180000.0  ...                                        NaN
#
#         CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 307488                                         NaN
# 307489                                         NaN
#
#         CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 307488                                        NaN
# 307489                                        NaN
#
#         CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 307488                                        NaN
# 307489                                        NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MIN  \
# 307488                                 NaN
# 307489                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 307488                                 NaN
# 307489                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 307488                                  NaN
# 307489                                  NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 307488                                 NaN
# 307489                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_COUNT
# 307488                                 NaN       NaN
# 307489                                 NaN       NaN
#
# [2 rows x 778 columns]
# (307488, 778)
#    SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      100002     1.0            0             0                0
# 1      100003     0.0            1             0                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          202500.0    406597.5      24700.5         351000.0
# 1             0          270000.0   1293502.5      35698.5        1129500.0
#
#    ...  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX  \
# 0  ...                                        NaN
# 1  ...                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# 0                                         NaN
# 1                                         NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# 0                                        NaN
# 1                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# 0                                        NaN
# 1                                        NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MIN  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_COUNT
# 0                                 NaN       NaN
# 1                                 NaN       NaN
#
# [2 rows x 778 columns]

# %%
data.TARGET.unique()
# Out:
# array([1., 0.])

# %%
data_test.TARGET.unique()
# Out:
# array([nan])

# %%
data.CC_NAME_CONTRACT_STATUS_Signed_VAR
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         0.0
# 4         NaN
#          ...
# 307483    NaN
# 307484    NaN
# 307485    NaN
# 307486    NaN
# 307487    NaN
# Name: CC_NAME_CONTRACT_STATUS_Signed_VAR, Length: 307488, dtype: float64

# %%
type(data.CC_NAME_CONTRACT_STATUS_Signed_VAR[2])
# Out:
# numpy.float64

# %%
type(np.nan) == type(data.CC_NAME_CONTRACT_STATUS_Signed_VAR[2])
# Out:
# False

# %%
float("NaN") == type(data.CC_NAME_CONTRACT_STATUS_Signed_VAR[2])
# Out:
# False

# %% [markdown]
# ### 2.2 Qualité de la données

# %% [markdown]
# - Dataset d'entraînement

# %%
data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307488 entries, 0 to 307487
# Data columns (total 778 columns):
#  #    Column                                                                 Non-Null Count   Dtype
# ---   ------                                                                 --------------   -----
#  0    SK_ID_CURR                                                             307488 non-null  int64
#  1    TARGET                                                                 307488 non-null  float64
#  2    CODE_GENDER                                                            307488 non-null  int64
#  3    FLAG_OWN_CAR                                                           307488 non-null  int64
#  4    FLAG_OWN_REALTY                                                        307488 non-null  int64
#  5    CNT_CHILDREN                                                           307488 non-null  int64
#  6    AMT_INCOME_TOTAL                                                       307488 non-null  float64
#  7    AMT_CREDIT                                                             307488 non-null  float64
#  8    AMT_ANNUITY                                                            307476 non-null  float64
#  9    AMT_GOODS_PRICE                                                        307210 non-null  float64
#  10   REGION_POPULATION_RELATIVE                                             307488 non-null  float64
#  11   DAYS_BIRTH                                                             307488 non-null  int64
#  12   DAYS_EMPLOYED                                                          252117 non-null  float64
#  13   DAYS_REGISTRATION                                                      307488 non-null  float64
#  14   DAYS_ID_PUBLISH                                                        307488 non-null  int64
#  15   OWN_CAR_AGE                                                            104573 non-null  float64
#  16   FLAG_MOBIL                                                             307488 non-null  int64
#  17   FLAG_EMP_PHONE                                                         307488 non-null  int64
#  18   FLAG_WORK_PHONE                                                        307488 non-null  int64
#  19   FLAG_CONT_MOBILE                                                       307488 non-null  int64
#  20   FLAG_PHONE                                                             307488 non-null  int64
#  21   FLAG_EMAIL                                                             307488 non-null  int64
#  22   CNT_FAM_MEMBERS                                                        307486 non-null  float64
#  23   REGION_RATING_CLIENT                                                   307488 non-null  int64
#  24   REGION_RATING_CLIENT_W_CITY                                            307488 non-null  int64
#  25   HOUR_APPR_PROCESS_START                                                307488 non-null  int64
#  26   REG_REGION_NOT_LIVE_REGION                                             307488 non-null  int64
#  27   REG_REGION_NOT_WORK_REGION                                             307488 non-null  int64
#  28   LIVE_REGION_NOT_WORK_REGION                                            307488 non-null  int64
#  29   REG_CITY_NOT_LIVE_CITY                                                 307488 non-null  int64
#  30   REG_CITY_NOT_WORK_CITY                                                 307488 non-null  int64
#  31   LIVE_CITY_NOT_WORK_CITY                                                307488 non-null  int64
#  32   EXT_SOURCE_1                                                           134129 non-null  float64
#  33   EXT_SOURCE_2                                                           306828 non-null  float64
#  34   EXT_SOURCE_3                                                           246528 non-null  float64
#  35   APARTMENTS_AVG                                                         151443 non-null  float64
#  36   BASEMENTAREA_AVG                                                       127562 non-null  float64
#  37   YEARS_BEGINEXPLUATATION_AVG                                            157498 non-null  float64
#  38   YEARS_BUILD_AVG                                                        103018 non-null  float64
#  39   COMMONAREA_AVG                                                         92641 non-null   float64
#  40   ELEVATORS_AVG                                                          143613 non-null  float64
#  41   ENTRANCES_AVG                                                          152676 non-null  float64
#  42   FLOORSMAX_AVG                                                          154484 non-null  float64
#  43   FLOORSMIN_AVG                                                          98863 non-null   float64
#  44   LANDAREA_AVG                                                           124916 non-null  float64
#  45   LIVINGAPARTMENTS_AVG                                                   97306 non-null   float64
#  46   LIVINGAREA_AVG                                                         153154 non-null  float64
#  47   NONLIVINGAPARTMENTS_AVG                                                93991 non-null   float64
#  48   NONLIVINGAREA_AVG                                                      137823 non-null  float64
#  49   APARTMENTS_MODE                                                        151443 non-null  float64
#  50   BASEMENTAREA_MODE                                                      127562 non-null  float64
#  51   YEARS_BEGINEXPLUATATION_MODE                                           157498 non-null  float64
#  52   YEARS_BUILD_MODE                                                       103018 non-null  float64
#  53   COMMONAREA_MODE                                                        92641 non-null   float64
#  54   ELEVATORS_MODE                                                         143613 non-null  float64
#  55   ENTRANCES_MODE                                                         152676 non-null  float64
#  56   FLOORSMAX_MODE                                                         154484 non-null  float64
#  57   FLOORSMIN_MODE                                                         98863 non-null   float64
#  58   LANDAREA_MODE                                                          124916 non-null  float64
#  59   LIVINGAPARTMENTS_MODE                                                  97306 non-null   float64
#  60   LIVINGAREA_MODE                                                        153154 non-null  float64
#  61   NONLIVINGAPARTMENTS_MODE                                               93991 non-null   float64
#  62   NONLIVINGAREA_MODE                                                     137823 non-null  float64
#  63   APARTMENTS_MEDI                                                        151443 non-null  float64
#  64   BASEMENTAREA_MEDI                                                      127562 non-null  float64
#  65   YEARS_BEGINEXPLUATATION_MEDI                                           157498 non-null  float64
#  66   YEARS_BUILD_MEDI                                                       103018 non-null  float64
#  67   COMMONAREA_MEDI                                                        92641 non-null   float64
#  68   ELEVATORS_MEDI                                                         143613 non-null  float64
#  69   ENTRANCES_MEDI                                                         152676 non-null  float64
#  70   FLOORSMAX_MEDI                                                         154484 non-null  float64
#  71   FLOORSMIN_MEDI                                                         98863 non-null   float64
#  72   LANDAREA_MEDI                                                          124916 non-null  float64
#  73   LIVINGAPARTMENTS_MEDI                                                  97306 non-null   float64
#  74   LIVINGAREA_MEDI                                                        153154 non-null  float64
#  75   NONLIVINGAPARTMENTS_MEDI                                               93991 non-null   float64
#  76   NONLIVINGAREA_MEDI                                                     137823 non-null  float64
#  77   TOTALAREA_MODE                                                         159073 non-null  float64
#  78   OBS_30_CNT_SOCIAL_CIRCLE                                               306467 non-null  float64
#  79   DEF_30_CNT_SOCIAL_CIRCLE                                               306467 non-null  float64
#  80   OBS_60_CNT_SOCIAL_CIRCLE                                               306467 non-null  float64
#  81   DEF_60_CNT_SOCIAL_CIRCLE                                               306467 non-null  float64
#  82   DAYS_LAST_PHONE_CHANGE                                                 307487 non-null  float64
#  83   FLAG_DOCUMENT_2                                                        307488 non-null  int64
#  84   FLAG_DOCUMENT_3                                                        307488 non-null  int64
#  85   FLAG_DOCUMENT_4                                                        307488 non-null  int64
#  86   FLAG_DOCUMENT_5                                                        307488 non-null  int64
#  87   FLAG_DOCUMENT_6                                                        307488 non-null  int64
#  88   FLAG_DOCUMENT_7                                                        307488 non-null  int64
#  89   FLAG_DOCUMENT_8                                                        307488 non-null  int64
#  90   FLAG_DOCUMENT_9                                                        307488 non-null  int64
#  91   FLAG_DOCUMENT_10                                                       307488 non-null  int64
#  92   FLAG_DOCUMENT_11                                                       307488 non-null  int64
#  93   FLAG_DOCUMENT_12                                                       307488 non-null  int64
#  94   FLAG_DOCUMENT_13                                                       307488 non-null  int64
#  95   FLAG_DOCUMENT_14                                                       307488 non-null  int64
#  96   FLAG_DOCUMENT_15                                                       307488 non-null  int64
#  97   FLAG_DOCUMENT_16                                                       307488 non-null  int64
#  98   FLAG_DOCUMENT_17                                                       307488 non-null  int64
#  99   FLAG_DOCUMENT_18                                                       307488 non-null  int64
#  100  FLAG_DOCUMENT_19                                                       307488 non-null  int64
#  101  FLAG_DOCUMENT_20                                                       307488 non-null  int64
#  102  FLAG_DOCUMENT_21                                                       307488 non-null  int64
#  103  AMT_REQ_CREDIT_BUREAU_HOUR                                             265974 non-null  float64
#  104  AMT_REQ_CREDIT_BUREAU_DAY                                              265974 non-null  float64
#  105  AMT_REQ_CREDIT_BUREAU_WEEK                                             265974 non-null  float64
#  106  AMT_REQ_CREDIT_BUREAU_MON                                              265974 non-null  float64
#  107  AMT_REQ_CREDIT_BUREAU_QRT                                              265974 non-null  float64
#  108  AMT_REQ_CREDIT_BUREAU_YEAR                                             265974 non-null  float64
#  109  NAME_CONTRACT_TYPE                                                     307488 non-null  float64
#  110  NAME_TYPE_SUITE_Children                                               307488 non-null  float64
#  111  NAME_TYPE_SUITE_Family                                                 307488 non-null  float64
#  112  NAME_TYPE_SUITE_Group of people                                        307488 non-null  float64
#  113  NAME_TYPE_SUITE_Other_A                                                307488 non-null  float64
#  114  NAME_TYPE_SUITE_Other_B                                                307488 non-null  float64
#  115  NAME_TYPE_SUITE_Spouse, partner                                        307488 non-null  float64
#  116  NAME_TYPE_SUITE_Unaccompanied                                          307488 non-null  float64
#  117  NAME_TYPE_SUITE_nan                                                    307488 non-null  float64
#  118  NAME_INCOME_TYPE_Businessman                                           307488 non-null  float64
#  119  NAME_INCOME_TYPE_Commercial associate                                  307488 non-null  float64
#  120  NAME_INCOME_TYPE_Maternity leave                                       307488 non-null  float64
#  121  NAME_INCOME_TYPE_Pensioner                                             307488 non-null  float64
#  122  NAME_INCOME_TYPE_State servant                                         307488 non-null  float64
#  123  NAME_INCOME_TYPE_Student                                               307488 non-null  float64
#  124  NAME_INCOME_TYPE_Unemployed                                            307488 non-null  float64
#  125  NAME_INCOME_TYPE_Working                                               307488 non-null  float64
#  126  NAME_EDUCATION_TYPE_Academic degree                                    307488 non-null  float64
#  127  NAME_EDUCATION_TYPE_Higher education                                   307488 non-null  float64
#  128  NAME_EDUCATION_TYPE_Incomplete higher                                  307488 non-null  float64
#  129  NAME_EDUCATION_TYPE_Lower secondary                                    307488 non-null  float64
#  130  NAME_EDUCATION_TYPE_Secondary / secondary special                      307488 non-null  float64
#  131  NAME_FAMILY_STATUS_Civil marriage                                      307488 non-null  float64
#  132  NAME_FAMILY_STATUS_Married                                             307488 non-null  float64
#  133  NAME_FAMILY_STATUS_Separated                                           307488 non-null  float64
#  134  NAME_FAMILY_STATUS_Single / not married                                307488 non-null  float64
#  135  NAME_FAMILY_STATUS_Unknown                                             307488 non-null  float64
#  136  NAME_FAMILY_STATUS_Widow                                               307488 non-null  float64
#  137  NAME_HOUSING_TYPE_Co-op apartment                                      307488 non-null  float64
#  138  NAME_HOUSING_TYPE_House / apartment                                    307488 non-null  float64
#  139  NAME_HOUSING_TYPE_Municipal apartment                                  307488 non-null  float64
#  140  NAME_HOUSING_TYPE_Office apartment                                     307488 non-null  float64
#  141  NAME_HOUSING_TYPE_Rented apartment                                     307488 non-null  float64
#  142  NAME_HOUSING_TYPE_With parents                                         307488 non-null  float64
#  143  OCCUPATION_TYPE_Accountants                                            307488 non-null  float64
#  144  OCCUPATION_TYPE_Cleaning staff                                         307488 non-null  float64
#  145  OCCUPATION_TYPE_Cooking staff                                          307488 non-null  float64
#  146  OCCUPATION_TYPE_Core staff                                             307488 non-null  float64
#  147  OCCUPATION_TYPE_Drivers                                                307488 non-null  float64
#  148  OCCUPATION_TYPE_HR staff                                               307488 non-null  float64
#  149  OCCUPATION_TYPE_High skill tech staff                                  307488 non-null  float64
#  150  OCCUPATION_TYPE_IT staff                                               307488 non-null  float64
#  151  OCCUPATION_TYPE_Laborers                                               307488 non-null  float64
#  152  OCCUPATION_TYPE_Low-skill Laborers                                     307488 non-null  float64
#  153  OCCUPATION_TYPE_Managers                                               307488 non-null  float64
#  154  OCCUPATION_TYPE_Medicine staff                                         307488 non-null  float64
#  155  OCCUPATION_TYPE_Private service staff                                  307488 non-null  float64
#  156  OCCUPATION_TYPE_Realty agents                                          307488 non-null  float64
#  157  OCCUPATION_TYPE_Sales staff                                            307488 non-null  float64
#  158  OCCUPATION_TYPE_Secretaries                                            307488 non-null  float64
#  159  OCCUPATION_TYPE_Security staff                                         307488 non-null  float64
#  160  OCCUPATION_TYPE_Waiters/barmen staff                                   307488 non-null  float64
#  161  OCCUPATION_TYPE_nan                                                    307488 non-null  float64
#  162  WEEKDAY_APPR_PROCESS_START_FRIDAY                                      307488 non-null  float64
#  163  WEEKDAY_APPR_PROCESS_START_MONDAY                                      307488 non-null  float64
#  164  WEEKDAY_APPR_PROCESS_START_SATURDAY                                    307488 non-null  float64
#  165  WEEKDAY_APPR_PROCESS_START_SUNDAY                                      307488 non-null  float64
#  166  WEEKDAY_APPR_PROCESS_START_THURSDAY                                    307488 non-null  float64
#  167  WEEKDAY_APPR_PROCESS_START_TUESDAY                                     307488 non-null  float64
#  168  WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                   307488 non-null  float64
#  169  ORGANIZATION_TYPE_Advertising                                          307488 non-null  float64
#  170  ORGANIZATION_TYPE_Agriculture                                          307488 non-null  float64
#  171  ORGANIZATION_TYPE_Bank                                                 307488 non-null  float64
#  172  ORGANIZATION_TYPE_Business Entity Type 1                               307488 non-null  float64
#  173  ORGANIZATION_TYPE_Business Entity Type 2                               307488 non-null  float64
#  174  ORGANIZATION_TYPE_Business Entity Type 3                               307488 non-null  float64
#  175  ORGANIZATION_TYPE_Cleaning                                             307488 non-null  float64
#  176  ORGANIZATION_TYPE_Construction                                         307488 non-null  float64
#  177  ORGANIZATION_TYPE_Culture                                              307488 non-null  float64
#  178  ORGANIZATION_TYPE_Electricity                                          307488 non-null  float64
#  179  ORGANIZATION_TYPE_Emergency                                            307488 non-null  float64
#  180  ORGANIZATION_TYPE_Government                                           307488 non-null  float64
#  181  ORGANIZATION_TYPE_Hotel                                                307488 non-null  float64
#  182  ORGANIZATION_TYPE_Housing                                              307488 non-null  float64
#  183  ORGANIZATION_TYPE_Industry: type 1                                     307488 non-null  float64
#  184  ORGANIZATION_TYPE_Industry: type 10                                    307488 non-null  float64
#  185  ORGANIZATION_TYPE_Industry: type 11                                    307488 non-null  float64
#  186  ORGANIZATION_TYPE_Industry: type 12                                    307488 non-null  float64
#  187  ORGANIZATION_TYPE_Industry: type 13                                    307488 non-null  float64
#  188  ORGANIZATION_TYPE_Industry: type 2                                     307488 non-null  float64
#  189  ORGANIZATION_TYPE_Industry: type 3                                     307488 non-null  float64
#  190  ORGANIZATION_TYPE_Industry: type 4                                     307488 non-null  float64
#  191  ORGANIZATION_TYPE_Industry: type 5                                     307488 non-null  float64
#  192  ORGANIZATION_TYPE_Industry: type 6                                     307488 non-null  float64
#  193  ORGANIZATION_TYPE_Industry: type 7                                     307488 non-null  float64
#  194  ORGANIZATION_TYPE_Industry: type 8                                     307488 non-null  float64
#  195  ORGANIZATION_TYPE_Industry: type 9                                     307488 non-null  float64
#  196  ORGANIZATION_TYPE_Insurance                                            307488 non-null  float64
#  197  ORGANIZATION_TYPE_Kindergarten                                         307488 non-null  float64
#  198  ORGANIZATION_TYPE_Legal Services                                       307488 non-null  float64
#  199  ORGANIZATION_TYPE_Medicine                                             307488 non-null  float64
#  200  ORGANIZATION_TYPE_Military                                             307488 non-null  float64
#  201  ORGANIZATION_TYPE_Mobile                                               307488 non-null  float64
#  202  ORGANIZATION_TYPE_Other                                                307488 non-null  float64
#  203  ORGANIZATION_TYPE_Police                                               307488 non-null  float64
#  204  ORGANIZATION_TYPE_Postal                                               307488 non-null  float64
#  205  ORGANIZATION_TYPE_Realtor                                              307488 non-null  float64
#  206  ORGANIZATION_TYPE_Religion                                             307488 non-null  float64
#  207  ORGANIZATION_TYPE_Restaurant                                           307488 non-null  float64
#  208  ORGANIZATION_TYPE_School                                               307488 non-null  float64
#  209  ORGANIZATION_TYPE_Security                                             307488 non-null  float64
#  210  ORGANIZATION_TYPE_Security Ministries                                  307488 non-null  float64
#  211  ORGANIZATION_TYPE_Self-employed                                        307488 non-null  float64
#  212  ORGANIZATION_TYPE_Services                                             307488 non-null  float64
#  213  ORGANIZATION_TYPE_Telecom                                              307488 non-null  float64
#  214  ORGANIZATION_TYPE_Trade: type 1                                        307488 non-null  float64
#  215  ORGANIZATION_TYPE_Trade: type 2                                        307488 non-null  float64
#  216  ORGANIZATION_TYPE_Trade: type 3                                        307488 non-null  float64
#  217  ORGANIZATION_TYPE_Trade: type 4                                        307488 non-null  float64
#  218  ORGANIZATION_TYPE_Trade: type 5                                        307488 non-null  float64
#  219  ORGANIZATION_TYPE_Trade: type 6                                        307488 non-null  float64
#  220  ORGANIZATION_TYPE_Trade: type 7                                        307488 non-null  float64
#  221  ORGANIZATION_TYPE_Transport: type 1                                    307488 non-null  float64
#  222  ORGANIZATION_TYPE_Transport: type 2                                    307488 non-null  float64
#  223  ORGANIZATION_TYPE_Transport: type 3                                    307488 non-null  float64
#  224  ORGANIZATION_TYPE_Transport: type 4                                    307488 non-null  float64
#  225  ORGANIZATION_TYPE_University                                           307488 non-null  float64
#  226  ORGANIZATION_TYPE_XNA                                                  307488 non-null  float64
#  227  FONDKAPREMONT_MODE_not specified                                       307488 non-null  float64
#  228  FONDKAPREMONT_MODE_org spec account                                    307488 non-null  float64
#  229  FONDKAPREMONT_MODE_reg oper account                                    307488 non-null  float64
#  230  FONDKAPREMONT_MODE_reg oper spec account                               307488 non-null  float64
#  231  FONDKAPREMONT_MODE_nan                                                 307488 non-null  float64
#  232  HOUSETYPE_MODE_block of flats                                          307488 non-null  float64
#  233  HOUSETYPE_MODE_specific housing                                        307488 non-null  float64
#  234  HOUSETYPE_MODE_terraced house                                          307488 non-null  float64
#  235  HOUSETYPE_MODE_nan                                                     307488 non-null  float64
#  236  WALLSMATERIAL_MODE_Block                                               307488 non-null  float64
#  237  WALLSMATERIAL_MODE_Mixed                                               307488 non-null  float64
#  238  WALLSMATERIAL_MODE_Monolithic                                          307488 non-null  float64
#  239  WALLSMATERIAL_MODE_Others                                              307488 non-null  float64
#  240  WALLSMATERIAL_MODE_Panel                                               307488 non-null  float64
#  241  WALLSMATERIAL_MODE_Stone, brick                                        307488 non-null  float64
#  242  WALLSMATERIAL_MODE_Wooden                                              307488 non-null  float64
#  243  WALLSMATERIAL_MODE_nan                                                 307488 non-null  float64
#  244  EMERGENCYSTATE_MODE_No                                                 307488 non-null  float64
#  245  EMERGENCYSTATE_MODE_Yes                                                307488 non-null  float64
#  246  EMERGENCYSTATE_MODE_nan                                                307488 non-null  float64
#  247  DAYS_EMPLOYED_ANOM                                                     307488 non-null  int64
#  248  DAYS_EMPLOYED_PERC                                                     252117 non-null  float64
#  249  INCOME_CREDIT_PERC                                                     307488 non-null  float64
#  250  INCOME_PER_PERSON                                                      307486 non-null  float64
#  251  ANNUITY_INCOME_PERC                                                    307476 non-null  float64
#  252  PAYMENT_RATE                                                           307476 non-null  float64
#  253  BURO_DAYS_CREDIT_MIN                                                   263474 non-null  float64
#  254  BURO_DAYS_CREDIT_MAX                                                   263474 non-null  float64
#  255  BURO_DAYS_CREDIT_MEAN                                                  263474 non-null  float64
#  256  BURO_DAYS_CREDIT_VAR                                                   227404 non-null  float64
#  257  BURO_DAYS_CREDIT_ENDDATE_MIN                                           261225 non-null  float64
#  258  BURO_DAYS_CREDIT_ENDDATE_MAX                                           261225 non-null  float64
#  259  BURO_DAYS_CREDIT_ENDDATE_MEAN                                          261225 non-null  float64
#  260  BURO_DAYS_CREDIT_UPDATE_MEAN                                           263474 non-null  float64
#  261  BURO_CREDIT_DAY_OVERDUE_MAX                                            263474 non-null  float64
#  262  BURO_CREDIT_DAY_OVERDUE_MEAN                                           263474 non-null  float64
#  263  BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                       183876 non-null  float64
#  264  BURO_AMT_CREDIT_SUM_MAX                                                263473 non-null  float64
#  265  BURO_AMT_CREDIT_SUM_MEAN                                               263473 non-null  float64
#  266  BURO_AMT_CREDIT_SUM_SUM                                                263474 non-null  float64
#  267  BURO_AMT_CREDIT_SUM_DEBT_MAX                                           256114 non-null  float64
#  268  BURO_AMT_CREDIT_SUM_DEBT_MEAN                                          256114 non-null  float64
#  269  BURO_AMT_CREDIT_SUM_DEBT_SUM                                           263474 non-null  float64
#  270  BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                       263474 non-null  float64
#  271  BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                         242425 non-null  float64
#  272  BURO_AMT_CREDIT_SUM_LIMIT_SUM                                          263474 non-null  float64
#  273  BURO_AMT_ANNUITY_MAX                                                   80004 non-null   float64
#  274  BURO_AMT_ANNUITY_MEAN                                                  80004 non-null   float64
#  275  BURO_CNT_CREDIT_PROLONG_SUM                                            263474 non-null  float64
#  276  BURO_MONTHS_BALANCE_MIN_MIN                                            92226 non-null   float64
#  277  BURO_MONTHS_BALANCE_MAX_MAX                                            92226 non-null   float64
#  278  BURO_MONTHS_BALANCE_SIZE_MEAN                                          92226 non-null   float64
#  279  BURO_MONTHS_BALANCE_SIZE_SUM                                           263474 non-null  float64
#  280  BURO_CREDIT_ACTIVE_Active_MEAN                                         263474 non-null  float64
#  281  BURO_CREDIT_ACTIVE_Bad debt_MEAN                                       263474 non-null  float64
#  282  BURO_CREDIT_ACTIVE_Closed_MEAN                                         263474 non-null  float64
#  283  BURO_CREDIT_ACTIVE_Sold_MEAN                                           263474 non-null  float64
#  284  BURO_CREDIT_CURRENCY_currency 1_MEAN                                   263474 non-null  float64
#  285  BURO_CREDIT_CURRENCY_currency 2_MEAN                                   263474 non-null  float64
#  286  BURO_CREDIT_CURRENCY_currency 3_MEAN                                   263474 non-null  float64
#  287  BURO_CREDIT_CURRENCY_currency 4_MEAN                                   263474 non-null  float64
#  288  BURO_CREDIT_TYPE_Another type of loan_MEAN                             263474 non-null  float64
#  289  BURO_CREDIT_TYPE_Car loan_MEAN                                         263474 non-null  float64
#  290  BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                        263474 non-null  float64
#  291  BURO_CREDIT_TYPE_Consumer credit_MEAN                                  263474 non-null  float64
#  292  BURO_CREDIT_TYPE_Credit card_MEAN                                      263474 non-null  float64
#  293  BURO_CREDIT_TYPE_Interbank credit_MEAN                                 263474 non-null  float64
#  294  BURO_CREDIT_TYPE_Loan for business development_MEAN                    263474 non-null  float64
#  295  BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN     263474 non-null  float64
#  296  BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN               263474 non-null  float64
#  297  BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN           263474 non-null  float64
#  298  BURO_CREDIT_TYPE_Microloan_MEAN                                        263474 non-null  float64
#  299  BURO_CREDIT_TYPE_Mobile operator loan_MEAN                             263474 non-null  float64
#  300  BURO_CREDIT_TYPE_Mortgage_MEAN                                         263474 non-null  float64
#  301  BURO_CREDIT_TYPE_Real estate loan_MEAN                                 263474 non-null  float64
#  302  BURO_CREDIT_TYPE_Unknown type of loan_MEAN                             263474 non-null  float64
#  303  BURO_STATUS_0_MEAN_MEAN                                                92226 non-null   float64
#  304  BURO_STATUS_1_MEAN_MEAN                                                92226 non-null   float64
#  305  BURO_STATUS_2_MEAN_MEAN                                                92226 non-null   float64
#  306  BURO_STATUS_3_MEAN_MEAN                                                92226 non-null   float64
#  307  BURO_STATUS_4_MEAN_MEAN                                                92226 non-null   float64
#  308  BURO_STATUS_5_MEAN_MEAN                                                92226 non-null   float64
#  309  BURO_STATUS_C_MEAN_MEAN                                                92226 non-null   float64
#  310  BURO_STATUS_X_MEAN_MEAN                                                92226 non-null   float64
#  311  ACTIVE_DAYS_CREDIT_MIN                                                 217136 non-null  float64
#  312  ACTIVE_DAYS_CREDIT_MAX                                                 217136 non-null  float64
#  313  ACTIVE_DAYS_CREDIT_MEAN                                                217136 non-null  float64
#  314  ACTIVE_DAYS_CREDIT_VAR                                                 143037 non-null  float64
#  315  ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                         208173 non-null  float64
#  316  ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                         208173 non-null  float64
#  317  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                        208173 non-null  float64
#  318  ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                         217136 non-null  float64
#  319  ACTIVE_CREDIT_DAY_OVERDUE_MAX                                          217136 non-null  float64
#  320  ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                         217136 non-null  float64
#  321  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                     116035 non-null  float64
#  322  ACTIVE_AMT_CREDIT_SUM_MAX                                              217135 non-null  float64
#  323  ACTIVE_AMT_CREDIT_SUM_MEAN                                             217135 non-null  float64
#  324  ACTIVE_AMT_CREDIT_SUM_SUM                                              217136 non-null  float64
#  325  ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                         206500 non-null  float64
#  326  ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                        206500 non-null  float64
#  327  ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                         217136 non-null  float64
#  328  ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                     217136 non-null  float64
#  329  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                       188715 non-null  float64
#  330  ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                        217136 non-null  float64
#  331  ACTIVE_AMT_ANNUITY_MAX                                                 61342 non-null   float64
#  332  ACTIVE_AMT_ANNUITY_MEAN                                                61342 non-null   float64
#  333  ACTIVE_CNT_CREDIT_PROLONG_SUM                                          217136 non-null  float64
#  334  ACTIVE_MONTHS_BALANCE_MIN_MIN                                          76515 non-null   float64
#  335  ACTIVE_MONTHS_BALANCE_MAX_MAX                                          76515 non-null   float64
#  336  ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                        76515 non-null   float64
#  337  ACTIVE_MONTHS_BALANCE_SIZE_SUM                                         217136 non-null  float64
#  338  CLOSED_DAYS_CREDIT_MIN                                                 230151 non-null  float64
#  339  CLOSED_DAYS_CREDIT_MAX                                                 230151 non-null  float64
#  340  CLOSED_DAYS_CREDIT_MEAN                                                230151 non-null  float64
#  341  CLOSED_DAYS_CREDIT_VAR                                                 176648 non-null  float64
#  342  CLOSED_DAYS_CREDIT_ENDDATE_MIN                                         228629 non-null  float64
#  343  CLOSED_DAYS_CREDIT_ENDDATE_MAX                                         228629 non-null  float64
#  344  CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                        228629 non-null  float64
#  345  CLOSED_DAYS_CREDIT_UPDATE_MEAN                                         230151 non-null  float64
#  346  CLOSED_CREDIT_DAY_OVERDUE_MAX                                          230151 non-null  float64
#  347  CLOSED_CREDIT_DAY_OVERDUE_MEAN                                         230151 non-null  float64
#  348  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                     146531 non-null  float64
#  349  CLOSED_AMT_CREDIT_SUM_MAX                                              230151 non-null  float64
#  350  CLOSED_AMT_CREDIT_SUM_MEAN                                             230151 non-null  float64
#  351  CLOSED_AMT_CREDIT_SUM_SUM                                              230151 non-null  float64
#  352  CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                         218319 non-null  float64
#  353  CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                        218319 non-null  float64
#  354  CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                         230151 non-null  float64
#  355  CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                     230151 non-null  float64
#  356  CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                       198959 non-null  float64
#  357  CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                        230151 non-null  float64
#  358  CLOSED_AMT_ANNUITY_MAX                                                 66005 non-null   float64
#  359  CLOSED_AMT_ANNUITY_MEAN                                                66005 non-null   float64
#  360  CLOSED_CNT_CREDIT_PROLONG_SUM                                          230151 non-null  float64
#  361  CLOSED_MONTHS_BALANCE_MIN_MIN                                          80731 non-null   float64
#  362  CLOSED_MONTHS_BALANCE_MAX_MAX                                          80731 non-null   float64
#  363  CLOSED_MONTHS_BALANCE_SIZE_MEAN                                        80731 non-null   float64
#  364  CLOSED_MONTHS_BALANCE_SIZE_SUM                                         230151 non-null  float64
#  365  PREV_AMT_ANNUITY_MIN                                                   290618 non-null  float64
#  366  PREV_AMT_ANNUITY_MAX                                                   290618 non-null  float64
#  367  PREV_AMT_ANNUITY_MEAN                                                  290618 non-null  float64
#  368  PREV_AMT_APPLICATION_MIN                                               291035 non-null  float64
#  369  PREV_AMT_APPLICATION_MAX                                               291035 non-null  float64
#  370  PREV_AMT_APPLICATION_MEAN                                              291035 non-null  float64
#  371  PREV_AMT_CREDIT_MIN                                                    291035 non-null  float64
#  372  PREV_AMT_CREDIT_MAX                                                    291035 non-null  float64
#  373  PREV_AMT_CREDIT_MEAN                                                   291035 non-null  float64
#  374  PREV_APP_CREDIT_PERC_MIN                                               290808 non-null  float64
#  375  PREV_APP_CREDIT_PERC_MAX                                               290808 non-null  float64
#  376  PREV_APP_CREDIT_PERC_MEAN                                              290808 non-null  float64
#  377  PREV_APP_CREDIT_PERC_VAR                                               229442 non-null  float64
#  378  PREV_AMT_DOWN_PAYMENT_MIN                                              273586 non-null  float64
#  379  PREV_AMT_DOWN_PAYMENT_MAX                                              273586 non-null  float64
#  380  PREV_AMT_DOWN_PAYMENT_MEAN                                             273586 non-null  float64
#  381  PREV_AMT_GOODS_PRICE_MIN                                               290060 non-null  float64
#  382  PREV_AMT_GOODS_PRICE_MAX                                               290060 non-null  float64
#  383  PREV_AMT_GOODS_PRICE_MEAN                                              290060 non-null  float64
#  384  PREV_HOUR_APPR_PROCESS_START_MIN                                       291035 non-null  float64
#  385  PREV_HOUR_APPR_PROCESS_START_MAX                                       291035 non-null  float64
#  386  PREV_HOUR_APPR_PROCESS_START_MEAN                                      291035 non-null  float64
#  387  PREV_RATE_DOWN_PAYMENT_MIN                                             273586 non-null  float64
#  388  PREV_RATE_DOWN_PAYMENT_MAX                                             273586 non-null  float64
#  389  PREV_RATE_DOWN_PAYMENT_MEAN                                            273586 non-null  float64
#  390  PREV_DAYS_DECISION_MIN                                                 291035 non-null  float64
#  391  PREV_DAYS_DECISION_MAX                                                 291035 non-null  float64
#  392  PREV_DAYS_DECISION_MEAN                                                291035 non-null  float64
#  393  PREV_CNT_PAYMENT_MEAN                                                  290620 non-null  float64
#  394  PREV_CNT_PAYMENT_SUM                                                   291035 non-null  float64
#  395  PREV_FLAG_LAST_APPL_PER_CONTRACT_MEAN                                  291035 non-null  float64
#  396  PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                291035 non-null  float64
#  397  PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                            291035 non-null  float64
#  398  PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                           291035 non-null  float64
#  399  PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                       291035 non-null  float64
#  400  PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                            291035 non-null  float64
#  401  PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                            291035 non-null  float64
#  402  PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                          291035 non-null  float64
#  403  PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                            291035 non-null  float64
#  404  PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                          291035 non-null  float64
#  405  PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                           291035 non-null  float64
#  406  PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                         291035 non-null  float64
#  407  PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN          291035 non-null  float64
#  408  PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                  291035 non-null  float64
#  409  PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                       291035 non-null  float64
#  410  PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN          291035 non-null  float64
#  411  PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                         291035 non-null  float64
#  412  PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                      291035 non-null  float64
#  413  PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                     291035 non-null  float64
#  414  PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                           291035 non-null  float64
#  415  PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                             291035 non-null  float64
#  416  PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                     291035 non-null  float64
#  417  PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                             291035 non-null  float64
#  418  PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN           291035 non-null  float64
#  419  PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                 291035 non-null  float64
#  420  PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                               291035 non-null  float64
#  421  PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                              291035 non-null  float64
#  422  PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN              291035 non-null  float64
#  423  PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                 291035 non-null  float64
#  424  PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN               291035 non-null  float64
#  425  PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN      291035 non-null  float64
#  426  PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN              291035 non-null  float64
#  427  PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                               291035 non-null  float64
#  428  PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                          291035 non-null  float64
#  429  PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN              291035 non-null  float64
#  430  PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                   291035 non-null  float64
#  431  PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                   291035 non-null  float64
#  432  PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                291035 non-null  float64
#  433  PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                291035 non-null  float64
#  434  PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                 291035 non-null  float64
#  435  PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                            291035 non-null  float64
#  436  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                      291035 non-null  float64
#  437  PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN  291035 non-null  float64
#  438  PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                 291035 non-null  float64
#  439  PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                        291035 non-null  float64
#  440  PREV_CODE_REJECT_REASON_CLIENT_MEAN                                    291035 non-null  float64
#  441  PREV_CODE_REJECT_REASON_HC_MEAN                                        291035 non-null  float64
#  442  PREV_CODE_REJECT_REASON_LIMIT_MEAN                                     291035 non-null  float64
#  443  PREV_CODE_REJECT_REASON_SCO_MEAN                                       291035 non-null  float64
#  444  PREV_CODE_REJECT_REASON_SCOFR_MEAN                                     291035 non-null  float64
#  445  PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                    291035 non-null  float64
#  446  PREV_CODE_REJECT_REASON_VERIF_MEAN                                     291035 non-null  float64
#  447  PREV_CODE_REJECT_REASON_XAP_MEAN                                       291035 non-null  float64
#  448  PREV_CODE_REJECT_REASON_XNA_MEAN                                       291035 non-null  float64
#  449  PREV_NAME_TYPE_SUITE_Children_MEAN                                     291035 non-null  float64
#  450  PREV_NAME_TYPE_SUITE_Family_MEAN                                       291035 non-null  float64
#  451  PREV_NAME_TYPE_SUITE_Group of people_MEAN                              291035 non-null  float64
#  452  PREV_NAME_TYPE_SUITE_Other_A_MEAN                                      291035 non-null  float64
#  453  PREV_NAME_TYPE_SUITE_Other_B_MEAN                                      291035 non-null  float64
#  454  PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                              291035 non-null  float64
#  455  PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                291035 non-null  float64
#  456  PREV_NAME_TYPE_SUITE_nan_MEAN                                          291035 non-null  float64
#  457  PREV_NAME_CLIENT_TYPE_New_MEAN                                         291035 non-null  float64
#  458  PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                   291035 non-null  float64
#  459  PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                    291035 non-null  float64
#  460  PREV_NAME_CLIENT_TYPE_XNA_MEAN                                         291035 non-null  float64
#  461  PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN                       291035 non-null  float64
#  462  PREV_NAME_GOODS_CATEGORY_Animals_MEAN                                  291035 non-null  float64
#  463  PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN                              291035 non-null  float64
#  464  PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                         291035 non-null  float64
#  465  PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                 291035 non-null  float64
#  466  PREV_NAME_GOODS_CATEGORY_Computers_MEAN                                291035 non-null  float64
# ...
#  622  INSTAL_DBD_SUM                                                         291620 non-null  float64
#  623  INSTAL_PAYMENT_PERC_MAX                                                291612 non-null  float64
#  624  INSTAL_PAYMENT_PERC_MEAN                                               291612 non-null  float64
#  625  INSTAL_PAYMENT_PERC_SUM                                                291620 non-null  float64
#  626  INSTAL_PAYMENT_PERC_VAR                                                290924 non-null  float64
#  627  INSTAL_PAYMENT_DIFF_MAX                                                291612 non-null  float64
#  628  INSTAL_PAYMENT_DIFF_MEAN                                               291612 non-null  float64
#  629  INSTAL_PAYMENT_DIFF_SUM                                                291620 non-null  float64
#  630  INSTAL_PAYMENT_DIFF_VAR                                                290924 non-null  float64
#  631  INSTAL_AMT_INSTALMENT_MAX                                              291620 non-null  float64
#  632  INSTAL_AMT_INSTALMENT_MEAN                                             291620 non-null  float64
#  633  INSTAL_AMT_INSTALMENT_SUM                                              291620 non-null  float64
#  634  INSTAL_AMT_PAYMENT_MIN                                                 291612 non-null  float64
#  635  INSTAL_AMT_PAYMENT_MAX                                                 291612 non-null  float64
#  636  INSTAL_AMT_PAYMENT_MEAN                                                291612 non-null  float64
#  637  INSTAL_AMT_PAYMENT_SUM                                                 291620 non-null  float64
#  638  INSTAL_DAYS_ENTRY_PAYMENT_MAX                                          291612 non-null  float64
#  639  INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                         291612 non-null  float64
#  640  INSTAL_DAYS_ENTRY_PAYMENT_SUM                                          291620 non-null  float64
#  641  INSTAL_COUNT                                                           291620 non-null  float64
#  642  CC_MONTHS_BALANCE_MIN                                                  86900 non-null   float64
#  643  CC_MONTHS_BALANCE_MAX                                                  86900 non-null   float64
#  644  CC_MONTHS_BALANCE_MEAN                                                 86900 non-null   float64
#  645  CC_MONTHS_BALANCE_SUM                                                  86900 non-null   float64
#  646  CC_MONTHS_BALANCE_VAR                                                  86268 non-null   float64
#  647  CC_AMT_BALANCE_MIN                                                     86900 non-null   float64
#  648  CC_AMT_BALANCE_MAX                                                     86900 non-null   float64
#  649  CC_AMT_BALANCE_MEAN                                                    86900 non-null   float64
#  650  CC_AMT_BALANCE_SUM                                                     86900 non-null   float64
#  651  CC_AMT_BALANCE_VAR                                                     86268 non-null   float64
#  652  CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                         86900 non-null   float64
#  653  CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                         86900 non-null   float64
#  654  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                        86900 non-null   float64
#  655  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                         86900 non-null   float64
#  656  CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                         86268 non-null   float64
#  657  CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                        61138 non-null   float64
#  658  CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                        61138 non-null   float64
#  659  CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                       61138 non-null   float64
#  660  CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                        86900 non-null   float64
#  661  CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                        60691 non-null   float64
#  662  CC_AMT_DRAWINGS_CURRENT_MIN                                            86900 non-null   float64
#  663  CC_AMT_DRAWINGS_CURRENT_MAX                                            86900 non-null   float64
#  664  CC_AMT_DRAWINGS_CURRENT_MEAN                                           86900 non-null   float64
#  665  CC_AMT_DRAWINGS_CURRENT_SUM                                            86900 non-null   float64
#  666  CC_AMT_DRAWINGS_CURRENT_VAR                                            86268 non-null   float64
#  667  CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                      61138 non-null   float64
#  668  CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                      61138 non-null   float64
#  669  CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                     61138 non-null   float64
#  670  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                      86900 non-null   float64
#  671  CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                      60691 non-null   float64
#  672  CC_AMT_DRAWINGS_POS_CURRENT_MIN                                        61138 non-null   float64
#  673  CC_AMT_DRAWINGS_POS_CURRENT_MAX                                        61138 non-null   float64
#  674  CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                       61138 non-null   float64
#  675  CC_AMT_DRAWINGS_POS_CURRENT_SUM                                        86900 non-null   float64
#  676  CC_AMT_DRAWINGS_POS_CURRENT_VAR                                        60691 non-null   float64
#  677  CC_AMT_INST_MIN_REGULARITY_MIN                                         86900 non-null   float64
#  678  CC_AMT_INST_MIN_REGULARITY_MAX                                         86900 non-null   float64
#  679  CC_AMT_INST_MIN_REGULARITY_MEAN                                        86900 non-null   float64
#  680  CC_AMT_INST_MIN_REGULARITY_SUM                                         86900 non-null   float64
#  681  CC_AMT_INST_MIN_REGULARITY_VAR                                         86268 non-null   float64
#  682  CC_AMT_PAYMENT_CURRENT_MIN                                             61058 non-null   float64
#  683  CC_AMT_PAYMENT_CURRENT_MAX                                             61058 non-null   float64
#  684  CC_AMT_PAYMENT_CURRENT_MEAN                                            61058 non-null   float64
#  685  CC_AMT_PAYMENT_CURRENT_SUM                                             86900 non-null   float64
#  686  CC_AMT_PAYMENT_CURRENT_VAR                                             60617 non-null   float64
#  687  CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                       86900 non-null   float64
#  688  CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                       86900 non-null   float64
#  689  CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                      86900 non-null   float64
#  690  CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                       86900 non-null   float64
#  691  CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                       86268 non-null   float64
#  692  CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                        86900 non-null   float64
#  693  CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                        86900 non-null   float64
#  694  CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                       86900 non-null   float64
#  695  CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                        86900 non-null   float64
#  696  CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                        86268 non-null   float64
#  697  CC_AMT_RECIVABLE_MIN                                                   86900 non-null   float64
#  698  CC_AMT_RECIVABLE_MAX                                                   86900 non-null   float64
#  699  CC_AMT_RECIVABLE_MEAN                                                  86900 non-null   float64
#  700  CC_AMT_RECIVABLE_SUM                                                   86900 non-null   float64
#  701  CC_AMT_RECIVABLE_VAR                                                   86268 non-null   float64
#  702  CC_AMT_TOTAL_RECEIVABLE_MIN                                            86900 non-null   float64
#  703  CC_AMT_TOTAL_RECEIVABLE_MAX                                            86900 non-null   float64
#  704  CC_AMT_TOTAL_RECEIVABLE_MEAN                                           86900 non-null   float64
#  705  CC_AMT_TOTAL_RECEIVABLE_SUM                                            86900 non-null   float64
#  706  CC_AMT_TOTAL_RECEIVABLE_VAR                                            86268 non-null   float64
#  707  CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                        61138 non-null   float64
#  708  CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                        61138 non-null   float64
#  709  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                       61138 non-null   float64
#  710  CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                        86900 non-null   float64
#  711  CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                        60691 non-null   float64
#  712  CC_CNT_DRAWINGS_CURRENT_MIN                                            86900 non-null   float64
#  713  CC_CNT_DRAWINGS_CURRENT_MAX                                            86900 non-null   float64
#  714  CC_CNT_DRAWINGS_CURRENT_MEAN                                           86900 non-null   float64
#  715  CC_CNT_DRAWINGS_CURRENT_SUM                                            86900 non-null   float64
#  716  CC_CNT_DRAWINGS_CURRENT_VAR                                            86268 non-null   float64
#  717  CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                      61138 non-null   float64
#  718  CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                      61138 non-null   float64
#  719  CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                     61138 non-null   float64
#  720  CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                      86900 non-null   float64
#  721  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                      60691 non-null   float64
#  722  CC_CNT_DRAWINGS_POS_CURRENT_MIN                                        61138 non-null   float64
#  723  CC_CNT_DRAWINGS_POS_CURRENT_MAX                                        61138 non-null   float64
#  724  CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                       61138 non-null   float64
#  725  CC_CNT_DRAWINGS_POS_CURRENT_SUM                                        86900 non-null   float64
#  726  CC_CNT_DRAWINGS_POS_CURRENT_VAR                                        60691 non-null   float64
#  727  CC_CNT_INSTALMENT_MATURE_CUM_MIN                                       86900 non-null   float64
#  728  CC_CNT_INSTALMENT_MATURE_CUM_MAX                                       86900 non-null   float64
#  729  CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                      86900 non-null   float64
#  730  CC_CNT_INSTALMENT_MATURE_CUM_SUM                                       86900 non-null   float64
#  731  CC_CNT_INSTALMENT_MATURE_CUM_VAR                                       86268 non-null   float64
#  732  CC_SK_DPD_MIN                                                          86900 non-null   float64
#  733  CC_SK_DPD_MAX                                                          86900 non-null   float64
#  734  CC_SK_DPD_MEAN                                                         86900 non-null   float64
#  735  CC_SK_DPD_SUM                                                          86900 non-null   float64
#  736  CC_SK_DPD_VAR                                                          86268 non-null   float64
#  737  CC_SK_DPD_DEF_MIN                                                      86900 non-null   float64
#  738  CC_SK_DPD_DEF_MAX                                                      86900 non-null   float64
#  739  CC_SK_DPD_DEF_MEAN                                                     86900 non-null   float64
#  740  CC_SK_DPD_DEF_SUM                                                      86900 non-null   float64
#  741  CC_SK_DPD_DEF_VAR                                                      86268 non-null   float64
#  742  CC_NAME_CONTRACT_STATUS_Active_MIN                                     86900 non-null   float64
#  743  CC_NAME_CONTRACT_STATUS_Active_MAX                                     86900 non-null   float64
#  744  CC_NAME_CONTRACT_STATUS_Active_MEAN                                    86900 non-null   float64
#  745  CC_NAME_CONTRACT_STATUS_Active_SUM                                     86900 non-null   float64
#  746  CC_NAME_CONTRACT_STATUS_Active_VAR                                     86268 non-null   float64
#  747  CC_NAME_CONTRACT_STATUS_Approved_MIN                                   86900 non-null   float64
#  748  CC_NAME_CONTRACT_STATUS_Approved_MAX                                   86900 non-null   float64
#  749  CC_NAME_CONTRACT_STATUS_Approved_MEAN                                  86900 non-null   float64
#  750  CC_NAME_CONTRACT_STATUS_Approved_SUM                                   86900 non-null   float64
#  751  CC_NAME_CONTRACT_STATUS_Approved_VAR                                   86268 non-null   float64
#  752  CC_NAME_CONTRACT_STATUS_Completed_MIN                                  86900 non-null   float64
#  753  CC_NAME_CONTRACT_STATUS_Completed_MAX                                  86900 non-null   float64
#  754  CC_NAME_CONTRACT_STATUS_Completed_MEAN                                 86900 non-null   float64
#  755  CC_NAME_CONTRACT_STATUS_Completed_SUM                                  86900 non-null   float64
#  756  CC_NAME_CONTRACT_STATUS_Completed_VAR                                  86268 non-null   float64
#  757  CC_NAME_CONTRACT_STATUS_Demand_MIN                                     86900 non-null   float64
#  758  CC_NAME_CONTRACT_STATUS_Demand_MAX                                     86900 non-null   float64
#  759  CC_NAME_CONTRACT_STATUS_Demand_MEAN                                    86900 non-null   float64
#  760  CC_NAME_CONTRACT_STATUS_Demand_SUM                                     86900 non-null   float64
#  761  CC_NAME_CONTRACT_STATUS_Demand_VAR                                     86268 non-null   float64
#  762  CC_NAME_CONTRACT_STATUS_Refused_MIN                                    86900 non-null   float64
#  763  CC_NAME_CONTRACT_STATUS_Refused_MAX                                    86900 non-null   float64
#  764  CC_NAME_CONTRACT_STATUS_Refused_MEAN                                   86900 non-null   float64
#  765  CC_NAME_CONTRACT_STATUS_Refused_SUM                                    86900 non-null   float64
#  766  CC_NAME_CONTRACT_STATUS_Refused_VAR                                    86268 non-null   float64
#  767  CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                              86900 non-null   float64
#  768  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                              86900 non-null   float64
#  769  CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                             86900 non-null   float64
#  770  CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                              86900 non-null   float64
#  771  CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                              86268 non-null   float64
#  772  CC_NAME_CONTRACT_STATUS_Signed_MIN                                     86900 non-null   float64
#  773  CC_NAME_CONTRACT_STATUS_Signed_MAX                                     86900 non-null   float64
#  774  CC_NAME_CONTRACT_STATUS_Signed_MEAN                                    86900 non-null   float64
#  775  CC_NAME_CONTRACT_STATUS_Signed_SUM                                     86900 non-null   float64
#  776  CC_NAME_CONTRACT_STATUS_Signed_VAR                                     86268 non-null   float64
#  777  CC_COUNT                                                               86900 non-null   float64
# dtypes: float64(735), int64(43)
# memory usage: 1.8 GB

# %%
print("Datastet train V1")
print(data.select_dtypes("object").columns)
# Out:
# Datastet train V1
# Index([], dtype='object')

# %% [markdown]
# - Dataset de test

# %%
data_test.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48743 entries, 307488 to 356230
# Data columns (total 778 columns):
#  #    Column                                                                 Non-Null Count  Dtype
# ---   ------                                                                 --------------  -----
#  0    SK_ID_CURR                                                             48743 non-null  int64
#  1    TARGET                                                                 0 non-null      float64
#  2    CODE_GENDER                                                            48743 non-null  int64
#  3    FLAG_OWN_CAR                                                           48743 non-null  int64
#  4    FLAG_OWN_REALTY                                                        48743 non-null  int64
#  5    CNT_CHILDREN                                                           48743 non-null  int64
#  6    AMT_INCOME_TOTAL                                                       48743 non-null  float64
#  7    AMT_CREDIT                                                             48743 non-null  float64
#  8    AMT_ANNUITY                                                            48719 non-null  float64
#  9    AMT_GOODS_PRICE                                                        48743 non-null  float64
#  10   REGION_POPULATION_RELATIVE                                             48743 non-null  float64
#  11   DAYS_BIRTH                                                             48743 non-null  int64
#  12   DAYS_EMPLOYED                                                          39469 non-null  float64
#  13   DAYS_REGISTRATION                                                      48743 non-null  float64
#  14   DAYS_ID_PUBLISH                                                        48743 non-null  int64
#  15   OWN_CAR_AGE                                                            16431 non-null  float64
#  16   FLAG_MOBIL                                                             48743 non-null  int64
#  17   FLAG_EMP_PHONE                                                         48743 non-null  int64
#  18   FLAG_WORK_PHONE                                                        48743 non-null  int64
#  19   FLAG_CONT_MOBILE                                                       48743 non-null  int64
#  20   FLAG_PHONE                                                             48743 non-null  int64
#  21   FLAG_EMAIL                                                             48743 non-null  int64
#  22   CNT_FAM_MEMBERS                                                        48743 non-null  float64
#  23   REGION_RATING_CLIENT                                                   48743 non-null  int64
#  24   REGION_RATING_CLIENT_W_CITY                                            48743 non-null  int64
#  25   HOUR_APPR_PROCESS_START                                                48743 non-null  int64
#  26   REG_REGION_NOT_LIVE_REGION                                             48743 non-null  int64
#  27   REG_REGION_NOT_WORK_REGION                                             48743 non-null  int64
#  28   LIVE_REGION_NOT_WORK_REGION                                            48743 non-null  int64
#  29   REG_CITY_NOT_LIVE_CITY                                                 48743 non-null  int64
#  30   REG_CITY_NOT_WORK_CITY                                                 48743 non-null  int64
#  31   LIVE_CITY_NOT_WORK_CITY                                                48743 non-null  int64
#  32   EXT_SOURCE_1                                                           28212 non-null  float64
#  33   EXT_SOURCE_2                                                           48735 non-null  float64
#  34   EXT_SOURCE_3                                                           40075 non-null  float64
#  35   APARTMENTS_AVG                                                         24857 non-null  float64
#  36   BASEMENTAREA_AVG                                                       21103 non-null  float64
#  37   YEARS_BEGINEXPLUATATION_AVG                                            25888 non-null  float64
#  38   YEARS_BUILD_AVG                                                        16926 non-null  float64
#  39   COMMONAREA_AVG                                                         15249 non-null  float64
#  40   ELEVATORS_AVG                                                          23555 non-null  float64
#  41   ENTRANCES_AVG                                                          25165 non-null  float64
#  42   FLOORSMAX_AVG                                                          25423 non-null  float64
#  43   FLOORSMIN_AVG                                                          16278 non-null  float64
#  44   LANDAREA_AVG                                                           20490 non-null  float64
#  45   LIVINGAPARTMENTS_AVG                                                   15964 non-null  float64
#  46   LIVINGAREA_AVG                                                         25192 non-null  float64
#  47   NONLIVINGAPARTMENTS_AVG                                                15397 non-null  float64
#  48   NONLIVINGAREA_AVG                                                      22660 non-null  float64
#  49   APARTMENTS_MODE                                                        24857 non-null  float64
#  50   BASEMENTAREA_MODE                                                      21103 non-null  float64
#  51   YEARS_BEGINEXPLUATATION_MODE                                           25888 non-null  float64
#  52   YEARS_BUILD_MODE                                                       16926 non-null  float64
#  53   COMMONAREA_MODE                                                        15249 non-null  float64
#  54   ELEVATORS_MODE                                                         23555 non-null  float64
#  55   ENTRANCES_MODE                                                         25165 non-null  float64
#  56   FLOORSMAX_MODE                                                         25423 non-null  float64
#  57   FLOORSMIN_MODE                                                         16278 non-null  float64
#  58   LANDAREA_MODE                                                          20490 non-null  float64
#  59   LIVINGAPARTMENTS_MODE                                                  15964 non-null  float64
#  60   LIVINGAREA_MODE                                                        25192 non-null  float64
#  61   NONLIVINGAPARTMENTS_MODE                                               15397 non-null  float64
#  62   NONLIVINGAREA_MODE                                                     22660 non-null  float64
#  63   APARTMENTS_MEDI                                                        24857 non-null  float64
#  64   BASEMENTAREA_MEDI                                                      21103 non-null  float64
#  65   YEARS_BEGINEXPLUATATION_MEDI                                           25888 non-null  float64
#  66   YEARS_BUILD_MEDI                                                       16926 non-null  float64
#  67   COMMONAREA_MEDI                                                        15249 non-null  float64
#  68   ELEVATORS_MEDI                                                         23555 non-null  float64
#  69   ENTRANCES_MEDI                                                         25165 non-null  float64
#  70   FLOORSMAX_MEDI                                                         25423 non-null  float64
#  71   FLOORSMIN_MEDI                                                         16278 non-null  float64
#  72   LANDAREA_MEDI                                                          20490 non-null  float64
#  73   LIVINGAPARTMENTS_MEDI                                                  15964 non-null  float64
#  74   LIVINGAREA_MEDI                                                        25192 non-null  float64
#  75   NONLIVINGAPARTMENTS_MEDI                                               15397 non-null  float64
#  76   NONLIVINGAREA_MEDI                                                     22660 non-null  float64
#  77   TOTALAREA_MODE                                                         26120 non-null  float64
#  78   OBS_30_CNT_SOCIAL_CIRCLE                                               48714 non-null  float64
#  79   DEF_30_CNT_SOCIAL_CIRCLE                                               48714 non-null  float64
#  80   OBS_60_CNT_SOCIAL_CIRCLE                                               48714 non-null  float64
#  81   DEF_60_CNT_SOCIAL_CIRCLE                                               48714 non-null  float64
#  82   DAYS_LAST_PHONE_CHANGE                                                 48743 non-null  float64
#  83   FLAG_DOCUMENT_2                                                        48743 non-null  int64
#  84   FLAG_DOCUMENT_3                                                        48743 non-null  int64
#  85   FLAG_DOCUMENT_4                                                        48743 non-null  int64
#  86   FLAG_DOCUMENT_5                                                        48743 non-null  int64
#  87   FLAG_DOCUMENT_6                                                        48743 non-null  int64
#  88   FLAG_DOCUMENT_7                                                        48743 non-null  int64
#  89   FLAG_DOCUMENT_8                                                        48743 non-null  int64
#  90   FLAG_DOCUMENT_9                                                        48743 non-null  int64
#  91   FLAG_DOCUMENT_10                                                       48743 non-null  int64
#  92   FLAG_DOCUMENT_11                                                       48743 non-null  int64
#  93   FLAG_DOCUMENT_12                                                       48743 non-null  int64
#  94   FLAG_DOCUMENT_13                                                       48743 non-null  int64
#  95   FLAG_DOCUMENT_14                                                       48743 non-null  int64
#  96   FLAG_DOCUMENT_15                                                       48743 non-null  int64
#  97   FLAG_DOCUMENT_16                                                       48743 non-null  int64
#  98   FLAG_DOCUMENT_17                                                       48743 non-null  int64
#  99   FLAG_DOCUMENT_18                                                       48743 non-null  int64
#  100  FLAG_DOCUMENT_19                                                       48743 non-null  int64
#  101  FLAG_DOCUMENT_20                                                       48743 non-null  int64
#  102  FLAG_DOCUMENT_21                                                       48743 non-null  int64
#  103  AMT_REQ_CREDIT_BUREAU_HOUR                                             42694 non-null  float64
#  104  AMT_REQ_CREDIT_BUREAU_DAY                                              42694 non-null  float64
#  105  AMT_REQ_CREDIT_BUREAU_WEEK                                             42694 non-null  float64
#  106  AMT_REQ_CREDIT_BUREAU_MON                                              42694 non-null  float64
#  107  AMT_REQ_CREDIT_BUREAU_QRT                                              42694 non-null  float64
#  108  AMT_REQ_CREDIT_BUREAU_YEAR                                             42694 non-null  float64
#  109  NAME_CONTRACT_TYPE                                                     48743 non-null  float64
#  110  NAME_TYPE_SUITE_Children                                               48743 non-null  float64
#  111  NAME_TYPE_SUITE_Family                                                 48743 non-null  float64
#  112  NAME_TYPE_SUITE_Group of people                                        48743 non-null  float64
#  113  NAME_TYPE_SUITE_Other_A                                                48743 non-null  float64
#  114  NAME_TYPE_SUITE_Other_B                                                48743 non-null  float64
#  115  NAME_TYPE_SUITE_Spouse, partner                                        48743 non-null  float64
#  116  NAME_TYPE_SUITE_Unaccompanied                                          48743 non-null  float64
#  117  NAME_TYPE_SUITE_nan                                                    48743 non-null  float64
#  118  NAME_INCOME_TYPE_Businessman                                           48743 non-null  float64
#  119  NAME_INCOME_TYPE_Commercial associate                                  48743 non-null  float64
#  120  NAME_INCOME_TYPE_Maternity leave                                       48743 non-null  float64
#  121  NAME_INCOME_TYPE_Pensioner                                             48743 non-null  float64
#  122  NAME_INCOME_TYPE_State servant                                         48743 non-null  float64
#  123  NAME_INCOME_TYPE_Student                                               48743 non-null  float64
#  124  NAME_INCOME_TYPE_Unemployed                                            48743 non-null  float64
#  125  NAME_INCOME_TYPE_Working                                               48743 non-null  float64
#  126  NAME_EDUCATION_TYPE_Academic degree                                    48743 non-null  float64
#  127  NAME_EDUCATION_TYPE_Higher education                                   48743 non-null  float64
#  128  NAME_EDUCATION_TYPE_Incomplete higher                                  48743 non-null  float64
#  129  NAME_EDUCATION_TYPE_Lower secondary                                    48743 non-null  float64
#  130  NAME_EDUCATION_TYPE_Secondary / secondary special                      48743 non-null  float64
#  131  NAME_FAMILY_STATUS_Civil marriage                                      48743 non-null  float64
#  132  NAME_FAMILY_STATUS_Married                                             48743 non-null  float64
#  133  NAME_FAMILY_STATUS_Separated                                           48743 non-null  float64
#  134  NAME_FAMILY_STATUS_Single / not married                                48743 non-null  float64
#  135  NAME_FAMILY_STATUS_Unknown                                             48743 non-null  float64
#  136  NAME_FAMILY_STATUS_Widow                                               48743 non-null  float64
#  137  NAME_HOUSING_TYPE_Co-op apartment                                      48743 non-null  float64
#  138  NAME_HOUSING_TYPE_House / apartment                                    48743 non-null  float64
#  139  NAME_HOUSING_TYPE_Municipal apartment                                  48743 non-null  float64
#  140  NAME_HOUSING_TYPE_Office apartment                                     48743 non-null  float64
#  141  NAME_HOUSING_TYPE_Rented apartment                                     48743 non-null  float64
#  142  NAME_HOUSING_TYPE_With parents                                         48743 non-null  float64
#  143  OCCUPATION_TYPE_Accountants                                            48743 non-null  float64
#  144  OCCUPATION_TYPE_Cleaning staff                                         48743 non-null  float64
#  145  OCCUPATION_TYPE_Cooking staff                                          48743 non-null  float64
#  146  OCCUPATION_TYPE_Core staff                                             48743 non-null  float64
#  147  OCCUPATION_TYPE_Drivers                                                48743 non-null  float64
#  148  OCCUPATION_TYPE_HR staff                                               48743 non-null  float64
#  149  OCCUPATION_TYPE_High skill tech staff                                  48743 non-null  float64
#  150  OCCUPATION_TYPE_IT staff                                               48743 non-null  float64
#  151  OCCUPATION_TYPE_Laborers                                               48743 non-null  float64
#  152  OCCUPATION_TYPE_Low-skill Laborers                                     48743 non-null  float64
#  153  OCCUPATION_TYPE_Managers                                               48743 non-null  float64
#  154  OCCUPATION_TYPE_Medicine staff                                         48743 non-null  float64
#  155  OCCUPATION_TYPE_Private service staff                                  48743 non-null  float64
#  156  OCCUPATION_TYPE_Realty agents                                          48743 non-null  float64
#  157  OCCUPATION_TYPE_Sales staff                                            48743 non-null  float64
#  158  OCCUPATION_TYPE_Secretaries                                            48743 non-null  float64
#  159  OCCUPATION_TYPE_Security staff                                         48743 non-null  float64
#  160  OCCUPATION_TYPE_Waiters/barmen staff                                   48743 non-null  float64
#  161  OCCUPATION_TYPE_nan                                                    48743 non-null  float64
#  162  WEEKDAY_APPR_PROCESS_START_FRIDAY                                      48743 non-null  float64
#  163  WEEKDAY_APPR_PROCESS_START_MONDAY                                      48743 non-null  float64
#  164  WEEKDAY_APPR_PROCESS_START_SATURDAY                                    48743 non-null  float64
#  165  WEEKDAY_APPR_PROCESS_START_SUNDAY                                      48743 non-null  float64
#  166  WEEKDAY_APPR_PROCESS_START_THURSDAY                                    48743 non-null  float64
#  167  WEEKDAY_APPR_PROCESS_START_TUESDAY                                     48743 non-null  float64
#  168  WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                   48743 non-null  float64
#  169  ORGANIZATION_TYPE_Advertising                                          48743 non-null  float64
#  170  ORGANIZATION_TYPE_Agriculture                                          48743 non-null  float64
#  171  ORGANIZATION_TYPE_Bank                                                 48743 non-null  float64
#  172  ORGANIZATION_TYPE_Business Entity Type 1                               48743 non-null  float64
#  173  ORGANIZATION_TYPE_Business Entity Type 2                               48743 non-null  float64
#  174  ORGANIZATION_TYPE_Business Entity Type 3                               48743 non-null  float64
#  175  ORGANIZATION_TYPE_Cleaning                                             48743 non-null  float64
#  176  ORGANIZATION_TYPE_Construction                                         48743 non-null  float64
#  177  ORGANIZATION_TYPE_Culture                                              48743 non-null  float64
#  178  ORGANIZATION_TYPE_Electricity                                          48743 non-null  float64
#  179  ORGANIZATION_TYPE_Emergency                                            48743 non-null  float64
#  180  ORGANIZATION_TYPE_Government                                           48743 non-null  float64
#  181  ORGANIZATION_TYPE_Hotel                                                48743 non-null  float64
#  182  ORGANIZATION_TYPE_Housing                                              48743 non-null  float64
#  183  ORGANIZATION_TYPE_Industry: type 1                                     48743 non-null  float64
#  184  ORGANIZATION_TYPE_Industry: type 10                                    48743 non-null  float64
#  185  ORGANIZATION_TYPE_Industry: type 11                                    48743 non-null  float64
#  186  ORGANIZATION_TYPE_Industry: type 12                                    48743 non-null  float64
#  187  ORGANIZATION_TYPE_Industry: type 13                                    48743 non-null  float64
#  188  ORGANIZATION_TYPE_Industry: type 2                                     48743 non-null  float64
#  189  ORGANIZATION_TYPE_Industry: type 3                                     48743 non-null  float64
#  190  ORGANIZATION_TYPE_Industry: type 4                                     48743 non-null  float64
#  191  ORGANIZATION_TYPE_Industry: type 5                                     48743 non-null  float64
#  192  ORGANIZATION_TYPE_Industry: type 6                                     48743 non-null  float64
#  193  ORGANIZATION_TYPE_Industry: type 7                                     48743 non-null  float64
#  194  ORGANIZATION_TYPE_Industry: type 8                                     48743 non-null  float64
#  195  ORGANIZATION_TYPE_Industry: type 9                                     48743 non-null  float64
#  196  ORGANIZATION_TYPE_Insurance                                            48743 non-null  float64
#  197  ORGANIZATION_TYPE_Kindergarten                                         48743 non-null  float64
#  198  ORGANIZATION_TYPE_Legal Services                                       48743 non-null  float64
#  199  ORGANIZATION_TYPE_Medicine                                             48743 non-null  float64
#  200  ORGANIZATION_TYPE_Military                                             48743 non-null  float64
#  201  ORGANIZATION_TYPE_Mobile                                               48743 non-null  float64
#  202  ORGANIZATION_TYPE_Other                                                48743 non-null  float64
#  203  ORGANIZATION_TYPE_Police                                               48743 non-null  float64
#  204  ORGANIZATION_TYPE_Postal                                               48743 non-null  float64
#  205  ORGANIZATION_TYPE_Realtor                                              48743 non-null  float64
#  206  ORGANIZATION_TYPE_Religion                                             48743 non-null  float64
#  207  ORGANIZATION_TYPE_Restaurant                                           48743 non-null  float64
#  208  ORGANIZATION_TYPE_School                                               48743 non-null  float64
#  209  ORGANIZATION_TYPE_Security                                             48743 non-null  float64
#  210  ORGANIZATION_TYPE_Security Ministries                                  48743 non-null  float64
#  211  ORGANIZATION_TYPE_Self-employed                                        48743 non-null  float64
#  212  ORGANIZATION_TYPE_Services                                             48743 non-null  float64
#  213  ORGANIZATION_TYPE_Telecom                                              48743 non-null  float64
#  214  ORGANIZATION_TYPE_Trade: type 1                                        48743 non-null  float64
#  215  ORGANIZATION_TYPE_Trade: type 2                                        48743 non-null  float64
#  216  ORGANIZATION_TYPE_Trade: type 3                                        48743 non-null  float64
#  217  ORGANIZATION_TYPE_Trade: type 4                                        48743 non-null  float64
#  218  ORGANIZATION_TYPE_Trade: type 5                                        48743 non-null  float64
#  219  ORGANIZATION_TYPE_Trade: type 6                                        48743 non-null  float64
#  220  ORGANIZATION_TYPE_Trade: type 7                                        48743 non-null  float64
#  221  ORGANIZATION_TYPE_Transport: type 1                                    48743 non-null  float64
#  222  ORGANIZATION_TYPE_Transport: type 2                                    48743 non-null  float64
#  223  ORGANIZATION_TYPE_Transport: type 3                                    48743 non-null  float64
#  224  ORGANIZATION_TYPE_Transport: type 4                                    48743 non-null  float64
#  225  ORGANIZATION_TYPE_University                                           48743 non-null  float64
#  226  ORGANIZATION_TYPE_XNA                                                  48743 non-null  float64
#  227  FONDKAPREMONT_MODE_not specified                                       48743 non-null  float64
#  228  FONDKAPREMONT_MODE_org spec account                                    48743 non-null  float64
#  229  FONDKAPREMONT_MODE_reg oper account                                    48743 non-null  float64
#  230  FONDKAPREMONT_MODE_reg oper spec account                               48743 non-null  float64
#  231  FONDKAPREMONT_MODE_nan                                                 48743 non-null  float64
#  232  HOUSETYPE_MODE_block of flats                                          48743 non-null  float64
#  233  HOUSETYPE_MODE_specific housing                                        48743 non-null  float64
#  234  HOUSETYPE_MODE_terraced house                                          48743 non-null  float64
#  235  HOUSETYPE_MODE_nan                                                     48743 non-null  float64
#  236  WALLSMATERIAL_MODE_Block                                               48743 non-null  float64
#  237  WALLSMATERIAL_MODE_Mixed                                               48743 non-null  float64
#  238  WALLSMATERIAL_MODE_Monolithic                                          48743 non-null  float64
#  239  WALLSMATERIAL_MODE_Others                                              48743 non-null  float64
#  240  WALLSMATERIAL_MODE_Panel                                               48743 non-null  float64
#  241  WALLSMATERIAL_MODE_Stone, brick                                        48743 non-null  float64
#  242  WALLSMATERIAL_MODE_Wooden                                              48743 non-null  float64
#  243  WALLSMATERIAL_MODE_nan                                                 48743 non-null  float64
#  244  EMERGENCYSTATE_MODE_No                                                 48743 non-null  float64
#  245  EMERGENCYSTATE_MODE_Yes                                                48743 non-null  float64
#  246  EMERGENCYSTATE_MODE_nan                                                48743 non-null  float64
#  247  DAYS_EMPLOYED_ANOM                                                     48743 non-null  int64
#  248  DAYS_EMPLOYED_PERC                                                     39469 non-null  float64
#  249  INCOME_CREDIT_PERC                                                     48743 non-null  float64
#  250  INCOME_PER_PERSON                                                      48743 non-null  float64
#  251  ANNUITY_INCOME_PERC                                                    48719 non-null  float64
#  252  PAYMENT_RATE                                                           48719 non-null  float64
#  253  BURO_DAYS_CREDIT_MIN                                                   42319 non-null  float64
#  254  BURO_DAYS_CREDIT_MAX                                                   42319 non-null  float64
#  255  BURO_DAYS_CREDIT_MEAN                                                  42319 non-null  float64
#  256  BURO_DAYS_CREDIT_VAR                                                   36871 non-null  float64
#  257  BURO_DAYS_CREDIT_ENDDATE_MIN                                           41983 non-null  float64
#  258  BURO_DAYS_CREDIT_ENDDATE_MAX                                           41983 non-null  float64
#  259  BURO_DAYS_CREDIT_ENDDATE_MEAN                                          41983 non-null  float64
#  260  BURO_DAYS_CREDIT_UPDATE_MEAN                                           42319 non-null  float64
#  261  BURO_CREDIT_DAY_OVERDUE_MAX                                            42319 non-null  float64
#  262  BURO_CREDIT_DAY_OVERDUE_MEAN                                           42319 non-null  float64
#  263  BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                       29085 non-null  float64
#  264  BURO_AMT_CREDIT_SUM_MAX                                                42318 non-null  float64
#  265  BURO_AMT_CREDIT_SUM_MEAN                                               42318 non-null  float64
#  266  BURO_AMT_CREDIT_SUM_SUM                                                42319 non-null  float64
#  267  BURO_AMT_CREDIT_SUM_DEBT_MAX                                           41307 non-null  float64
#  268  BURO_AMT_CREDIT_SUM_DEBT_MEAN                                          41307 non-null  float64
#  269  BURO_AMT_CREDIT_SUM_DEBT_SUM                                           42319 non-null  float64
#  270  BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                       42319 non-null  float64
#  271  BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                         38060 non-null  float64
#  272  BURO_AMT_CREDIT_SUM_LIMIT_SUM                                          42319 non-null  float64
#  273  BURO_AMT_ANNUITY_MAX                                                   38214 non-null  float64
#  274  BURO_AMT_ANNUITY_MEAN                                                  38214 non-null  float64
#  275  BURO_CNT_CREDIT_PROLONG_SUM                                            42319 non-null  float64
#  276  BURO_MONTHS_BALANCE_MIN_MIN                                            42310 non-null  float64
#  277  BURO_MONTHS_BALANCE_MAX_MAX                                            42310 non-null  float64
#  278  BURO_MONTHS_BALANCE_SIZE_MEAN                                          42310 non-null  float64
#  279  BURO_MONTHS_BALANCE_SIZE_SUM                                           42319 non-null  float64
#  280  BURO_CREDIT_ACTIVE_Active_MEAN                                         42319 non-null  float64
#  281  BURO_CREDIT_ACTIVE_Bad debt_MEAN                                       42319 non-null  float64
#  282  BURO_CREDIT_ACTIVE_Closed_MEAN                                         42319 non-null  float64
#  283  BURO_CREDIT_ACTIVE_Sold_MEAN                                           42319 non-null  float64
#  284  BURO_CREDIT_CURRENCY_currency 1_MEAN                                   42319 non-null  float64
#  285  BURO_CREDIT_CURRENCY_currency 2_MEAN                                   42319 non-null  float64
#  286  BURO_CREDIT_CURRENCY_currency 3_MEAN                                   42319 non-null  float64
#  287  BURO_CREDIT_CURRENCY_currency 4_MEAN                                   42319 non-null  float64
#  288  BURO_CREDIT_TYPE_Another type of loan_MEAN                             42319 non-null  float64
#  289  BURO_CREDIT_TYPE_Car loan_MEAN                                         42319 non-null  float64
#  290  BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                        42319 non-null  float64
#  291  BURO_CREDIT_TYPE_Consumer credit_MEAN                                  42319 non-null  float64
#  292  BURO_CREDIT_TYPE_Credit card_MEAN                                      42319 non-null  float64
#  293  BURO_CREDIT_TYPE_Interbank credit_MEAN                                 42319 non-null  float64
#  294  BURO_CREDIT_TYPE_Loan for business development_MEAN                    42319 non-null  float64
#  295  BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN     42319 non-null  float64
#  296  BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN               42319 non-null  float64
#  297  BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN           42319 non-null  float64
#  298  BURO_CREDIT_TYPE_Microloan_MEAN                                        42319 non-null  float64
#  299  BURO_CREDIT_TYPE_Mobile operator loan_MEAN                             42319 non-null  float64
#  300  BURO_CREDIT_TYPE_Mortgage_MEAN                                         42319 non-null  float64
#  301  BURO_CREDIT_TYPE_Real estate loan_MEAN                                 42319 non-null  float64
#  302  BURO_CREDIT_TYPE_Unknown type of loan_MEAN                             42319 non-null  float64
#  303  BURO_STATUS_0_MEAN_MEAN                                                42310 non-null  float64
#  304  BURO_STATUS_1_MEAN_MEAN                                                42310 non-null  float64
#  305  BURO_STATUS_2_MEAN_MEAN                                                42310 non-null  float64
#  306  BURO_STATUS_3_MEAN_MEAN                                                42310 non-null  float64
#  307  BURO_STATUS_4_MEAN_MEAN                                                42310 non-null  float64
#  308  BURO_STATUS_5_MEAN_MEAN                                                42310 non-null  float64
#  309  BURO_STATUS_C_MEAN_MEAN                                                42310 non-null  float64
#  310  BURO_STATUS_X_MEAN_MEAN                                                42310 non-null  float64
#  311  ACTIVE_DAYS_CREDIT_MIN                                                 34664 non-null  float64
#  312  ACTIVE_DAYS_CREDIT_MAX                                                 34664 non-null  float64
#  313  ACTIVE_DAYS_CREDIT_MEAN                                                34664 non-null  float64
#  314  ACTIVE_DAYS_CREDIT_VAR                                                 23279 non-null  float64
#  315  ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                         33158 non-null  float64
#  316  ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                         33158 non-null  float64
#  317  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                        33158 non-null  float64
#  318  ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                         34664 non-null  float64
#  319  ACTIVE_CREDIT_DAY_OVERDUE_MAX                                          34664 non-null  float64
#  320  ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                         34664 non-null  float64
#  321  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                     16960 non-null  float64
#  322  ACTIVE_AMT_CREDIT_SUM_MAX                                              34662 non-null  float64
#  323  ACTIVE_AMT_CREDIT_SUM_MEAN                                             34662 non-null  float64
#  324  ACTIVE_AMT_CREDIT_SUM_SUM                                              34664 non-null  float64
#  325  ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                         33349 non-null  float64
#  326  ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                        33349 non-null  float64
#  327  ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                         34664 non-null  float64
#  328  ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                     34664 non-null  float64
#  329  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                       29375 non-null  float64
#  330  ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                        34664 non-null  float64
#  331  ACTIVE_AMT_ANNUITY_MAX                                                 31379 non-null  float64
#  332  ACTIVE_AMT_ANNUITY_MEAN                                                31379 non-null  float64
#  333  ACTIVE_CNT_CREDIT_PROLONG_SUM                                          34664 non-null  float64
#  334  ACTIVE_MONTHS_BALANCE_MIN_MIN                                          34629 non-null  float64
#  335  ACTIVE_MONTHS_BALANCE_MAX_MAX                                          34629 non-null  float64
#  336  ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                        34629 non-null  float64
#  337  ACTIVE_MONTHS_BALANCE_SIZE_SUM                                         34664 non-null  float64
#  338  CLOSED_DAYS_CREDIT_MIN                                                 37760 non-null  float64
#  339  CLOSED_DAYS_CREDIT_MAX                                                 37760 non-null  float64
#  340  CLOSED_DAYS_CREDIT_MEAN                                                37760 non-null  float64
#  341  CLOSED_DAYS_CREDIT_VAR                                                 29570 non-null  float64
#  342  CLOSED_DAYS_CREDIT_ENDDATE_MIN                                         37529 non-null  float64
#  343  CLOSED_DAYS_CREDIT_ENDDATE_MAX                                         37529 non-null  float64
#  344  CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                        37529 non-null  float64
#  345  CLOSED_DAYS_CREDIT_UPDATE_MEAN                                         37760 non-null  float64
#  346  CLOSED_CREDIT_DAY_OVERDUE_MAX                                          37760 non-null  float64
#  347  CLOSED_CREDIT_DAY_OVERDUE_MEAN                                         37760 non-null  float64
#  348  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                     23359 non-null  float64
#  349  CLOSED_AMT_CREDIT_SUM_MAX                                              37760 non-null  float64
#  350  CLOSED_AMT_CREDIT_SUM_MEAN                                             37760 non-null  float64
#  351  CLOSED_AMT_CREDIT_SUM_SUM                                              37760 non-null  float64
#  352  CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                         36003 non-null  float64
#  353  CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                        36003 non-null  float64
#  354  CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                         37760 non-null  float64
#  355  CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                     37760 non-null  float64
#  356  CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                       30969 non-null  float64
#  357  CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                        37760 non-null  float64
#  358  CLOSED_AMT_ANNUITY_MAX                                                 29188 non-null  float64
#  359  CLOSED_AMT_ANNUITY_MEAN                                                29188 non-null  float64
#  360  CLOSED_CNT_CREDIT_PROLONG_SUM                                          37760 non-null  float64
#  361  CLOSED_MONTHS_BALANCE_MIN_MIN                                          37760 non-null  float64
#  362  CLOSED_MONTHS_BALANCE_MAX_MAX                                          37760 non-null  float64
#  363  CLOSED_MONTHS_BALANCE_SIZE_MEAN                                        37760 non-null  float64
#  364  CLOSED_MONTHS_BALANCE_SIZE_SUM                                         37760 non-null  float64
#  365  PREV_AMT_ANNUITY_MIN                                                   47736 non-null  float64
#  366  PREV_AMT_ANNUITY_MAX                                                   47736 non-null  float64
#  367  PREV_AMT_ANNUITY_MEAN                                                  47736 non-null  float64
#  368  PREV_AMT_APPLICATION_MIN                                               47799 non-null  float64
#  369  PREV_AMT_APPLICATION_MAX                                               47799 non-null  float64
#  370  PREV_AMT_APPLICATION_MEAN                                              47799 non-null  float64
#  371  PREV_AMT_CREDIT_MIN                                                    47799 non-null  float64
#  372  PREV_AMT_CREDIT_MAX                                                    47799 non-null  float64
#  373  PREV_AMT_CREDIT_MEAN                                                   47799 non-null  float64
#  374  PREV_APP_CREDIT_PERC_MIN                                               47774 non-null  float64
#  375  PREV_APP_CREDIT_PERC_MAX                                               47774 non-null  float64
#  376  PREV_APP_CREDIT_PERC_MEAN                                              47774 non-null  float64
#  377  PREV_APP_CREDIT_PERC_VAR                                               38360 non-null  float64
#  378  PREV_AMT_DOWN_PAYMENT_MIN                                              45147 non-null  float64
#  379  PREV_AMT_DOWN_PAYMENT_MAX                                              45147 non-null  float64
#  380  PREV_AMT_DOWN_PAYMENT_MEAN                                             45147 non-null  float64
#  381  PREV_AMT_GOODS_PRICE_MIN                                               47710 non-null  float64
#  382  PREV_AMT_GOODS_PRICE_MAX                                               47710 non-null  float64
#  383  PREV_AMT_GOODS_PRICE_MEAN                                              47710 non-null  float64
#  384  PREV_HOUR_APPR_PROCESS_START_MIN                                       47799 non-null  float64
#  385  PREV_HOUR_APPR_PROCESS_START_MAX                                       47799 non-null  float64
#  386  PREV_HOUR_APPR_PROCESS_START_MEAN                                      47799 non-null  float64
#  387  PREV_RATE_DOWN_PAYMENT_MIN                                             45147 non-null  float64
#  388  PREV_RATE_DOWN_PAYMENT_MAX                                             45147 non-null  float64
#  389  PREV_RATE_DOWN_PAYMENT_MEAN                                            45147 non-null  float64
#  390  PREV_DAYS_DECISION_MIN                                                 47799 non-null  float64
#  391  PREV_DAYS_DECISION_MAX                                                 47799 non-null  float64
#  392  PREV_DAYS_DECISION_MEAN                                                47799 non-null  float64
#  393  PREV_CNT_PAYMENT_MEAN                                                  47736 non-null  float64
#  394  PREV_CNT_PAYMENT_SUM                                                   47799 non-null  float64
#  395  PREV_FLAG_LAST_APPL_PER_CONTRACT_MEAN                                  47799 non-null  float64
#  396  PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                47799 non-null  float64
#  397  PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                            47799 non-null  float64
#  398  PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                           47799 non-null  float64
#  399  PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                       47799 non-null  float64
#  400  PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                            47799 non-null  float64
#  401  PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                            47799 non-null  float64
#  402  PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                          47799 non-null  float64
#  403  PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                            47799 non-null  float64
#  404  PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                          47799 non-null  float64
#  405  PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                           47799 non-null  float64
#  406  PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                         47799 non-null  float64
#  407  PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN          47799 non-null  float64
#  408  PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                  47799 non-null  float64
#  409  PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                       47799 non-null  float64
#  410  PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN          47799 non-null  float64
#  411  PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                         47799 non-null  float64
#  412  PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                      47799 non-null  float64
#  413  PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                     47799 non-null  float64
#  414  PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                           47799 non-null  float64
#  415  PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                             47799 non-null  float64
#  416  PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                     47799 non-null  float64
#  417  PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                             47799 non-null  float64
#  418  PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN           47799 non-null  float64
#  419  PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                 47799 non-null  float64
#  420  PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                               47799 non-null  float64
#  421  PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                              47799 non-null  float64
#  422  PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN              47799 non-null  float64
#  423  PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                 47799 non-null  float64
#  424  PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN               47799 non-null  float64
#  425  PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN      47799 non-null  float64
#  426  PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN              47799 non-null  float64
#  427  PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                               47799 non-null  float64
#  428  PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                          47799 non-null  float64
#  429  PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN              47799 non-null  float64
#  430  PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                   47799 non-null  float64
#  431  PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                   47799 non-null  float64
#  432  PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                47799 non-null  float64
#  433  PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                47799 non-null  float64
#  434  PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                 47799 non-null  float64
#  435  PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                            47799 non-null  float64
#  436  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                      47799 non-null  float64
#  437  PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN  47799 non-null  float64
#  438  PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                 47799 non-null  float64
#  439  PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                        47799 non-null  float64
#  440  PREV_CODE_REJECT_REASON_CLIENT_MEAN                                    47799 non-null  float64
#  441  PREV_CODE_REJECT_REASON_HC_MEAN                                        47799 non-null  float64
#  442  PREV_CODE_REJECT_REASON_LIMIT_MEAN                                     47799 non-null  float64
#  443  PREV_CODE_REJECT_REASON_SCO_MEAN                                       47799 non-null  float64
#  444  PREV_CODE_REJECT_REASON_SCOFR_MEAN                                     47799 non-null  float64
#  445  PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                    47799 non-null  float64
#  446  PREV_CODE_REJECT_REASON_VERIF_MEAN                                     47799 non-null  float64
#  447  PREV_CODE_REJECT_REASON_XAP_MEAN                                       47799 non-null  float64
#  448  PREV_CODE_REJECT_REASON_XNA_MEAN                                       47799 non-null  float64
#  449  PREV_NAME_TYPE_SUITE_Children_MEAN                                     47799 non-null  float64
#  450  PREV_NAME_TYPE_SUITE_Family_MEAN                                       47799 non-null  float64
#  451  PREV_NAME_TYPE_SUITE_Group of people_MEAN                              47799 non-null  float64
#  452  PREV_NAME_TYPE_SUITE_Other_A_MEAN                                      47799 non-null  float64
#  453  PREV_NAME_TYPE_SUITE_Other_B_MEAN                                      47799 non-null  float64
#  454  PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                              47799 non-null  float64
#  455  PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                47799 non-null  float64
#  456  PREV_NAME_TYPE_SUITE_nan_MEAN                                          47799 non-null  float64
#  457  PREV_NAME_CLIENT_TYPE_New_MEAN                                         47799 non-null  float64
#  458  PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                   47799 non-null  float64
#  459  PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                    47799 non-null  float64
#  460  PREV_NAME_CLIENT_TYPE_XNA_MEAN                                         47799 non-null  float64
#  461  PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN                       47799 non-null  float64
#  462  PREV_NAME_GOODS_CATEGORY_Animals_MEAN                                  47799 non-null  float64
#  463  PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN                              47799 non-null  float64
#  464  PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                         47799 non-null  float64
#  465  PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                 47799 non-null  float64
#  466  PREV_NAME_GOODS_CATEGORY_Computers_MEAN                                47799 non-null  float64
#  467  PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN                   47799 non-null  float64
#  468  PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN                     47799 non-null  float64
#  469  PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN                             47799 non-null  float64
#  470  PREV_NAME_GOODS_CATEGORY_Education_MEAN                                47799 non-null  float64
#  471  PREV_NAME_GOODS_CATEGORY_Fitness_MEAN                                  47799 non-null  float64
# ...
#  621  INSTAL_DBD_MEAN                                                        47943 non-null  float64
#  622  INSTAL_DBD_SUM                                                         47943 non-null  float64
#  623  INSTAL_PAYMENT_PERC_MAX                                                47942 non-null  float64
#  624  INSTAL_PAYMENT_PERC_MEAN                                               47942 non-null  float64
#  625  INSTAL_PAYMENT_PERC_SUM                                                47943 non-null  float64
#  626  INSTAL_PAYMENT_PERC_VAR                                                47662 non-null  float64
#  627  INSTAL_PAYMENT_DIFF_MAX                                                47942 non-null  float64
#  628  INSTAL_PAYMENT_DIFF_MEAN                                               47942 non-null  float64
#  629  INSTAL_PAYMENT_DIFF_SUM                                                47943 non-null  float64
#  630  INSTAL_PAYMENT_DIFF_VAR                                                47662 non-null  float64
#  631  INSTAL_AMT_INSTALMENT_MAX                                              47943 non-null  float64
#  632  INSTAL_AMT_INSTALMENT_MEAN                                             47943 non-null  float64
#  633  INSTAL_AMT_INSTALMENT_SUM                                              47943 non-null  float64
#  634  INSTAL_AMT_PAYMENT_MIN                                                 47942 non-null  float64
#  635  INSTAL_AMT_PAYMENT_MAX                                                 47942 non-null  float64
#  636  INSTAL_AMT_PAYMENT_MEAN                                                47942 non-null  float64
#  637  INSTAL_AMT_PAYMENT_SUM                                                 47943 non-null  float64
#  638  INSTAL_DAYS_ENTRY_PAYMENT_MAX                                          47942 non-null  float64
#  639  INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                         47942 non-null  float64
#  640  INSTAL_DAYS_ENTRY_PAYMENT_SUM                                          47943 non-null  float64
#  641  INSTAL_COUNT                                                           47943 non-null  float64
#  642  CC_MONTHS_BALANCE_MIN                                                  16652 non-null  float64
#  643  CC_MONTHS_BALANCE_MAX                                                  16652 non-null  float64
#  644  CC_MONTHS_BALANCE_MEAN                                                 16652 non-null  float64
#  645  CC_MONTHS_BALANCE_SUM                                                  16652 non-null  float64
#  646  CC_MONTHS_BALANCE_VAR                                                  16592 non-null  float64
#  647  CC_AMT_BALANCE_MIN                                                     16652 non-null  float64
#  648  CC_AMT_BALANCE_MAX                                                     16652 non-null  float64
#  649  CC_AMT_BALANCE_MEAN                                                    16652 non-null  float64
#  650  CC_AMT_BALANCE_SUM                                                     16652 non-null  float64
#  651  CC_AMT_BALANCE_VAR                                                     16592 non-null  float64
#  652  CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                         16652 non-null  float64
#  653  CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                         16652 non-null  float64
#  654  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                        16652 non-null  float64
#  655  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                         16652 non-null  float64
#  656  CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                         16592 non-null  float64
#  657  CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                        11053 non-null  float64
#  658  CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                        11053 non-null  float64
#  659  CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                       11053 non-null  float64
#  660  CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                        16652 non-null  float64
#  661  CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                        10998 non-null  float64
#  662  CC_AMT_DRAWINGS_CURRENT_MIN                                            16652 non-null  float64
#  663  CC_AMT_DRAWINGS_CURRENT_MAX                                            16652 non-null  float64
#  664  CC_AMT_DRAWINGS_CURRENT_MEAN                                           16652 non-null  float64
#  665  CC_AMT_DRAWINGS_CURRENT_SUM                                            16652 non-null  float64
#  666  CC_AMT_DRAWINGS_CURRENT_VAR                                            16592 non-null  float64
#  667  CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                      11053 non-null  float64
#  668  CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                      11053 non-null  float64
#  669  CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                     11053 non-null  float64
#  670  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                      16652 non-null  float64
#  671  CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                      10998 non-null  float64
#  672  CC_AMT_DRAWINGS_POS_CURRENT_MIN                                        11053 non-null  float64
#  673  CC_AMT_DRAWINGS_POS_CURRENT_MAX                                        11053 non-null  float64
#  674  CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                       11053 non-null  float64
#  675  CC_AMT_DRAWINGS_POS_CURRENT_SUM                                        16652 non-null  float64
#  676  CC_AMT_DRAWINGS_POS_CURRENT_VAR                                        10998 non-null  float64
#  677  CC_AMT_INST_MIN_REGULARITY_MIN                                         16652 non-null  float64
#  678  CC_AMT_INST_MIN_REGULARITY_MAX                                         16652 non-null  float64
#  679  CC_AMT_INST_MIN_REGULARITY_MEAN                                        16652 non-null  float64
#  680  CC_AMT_INST_MIN_REGULARITY_SUM                                         16652 non-null  float64
#  681  CC_AMT_INST_MIN_REGULARITY_VAR                                         16592 non-null  float64
#  682  CC_AMT_PAYMENT_CURRENT_MIN                                             11059 non-null  float64
#  683  CC_AMT_PAYMENT_CURRENT_MAX                                             11059 non-null  float64
#  684  CC_AMT_PAYMENT_CURRENT_MEAN                                            11059 non-null  float64
#  685  CC_AMT_PAYMENT_CURRENT_SUM                                             16652 non-null  float64
#  686  CC_AMT_PAYMENT_CURRENT_VAR                                             10982 non-null  float64
#  687  CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                       16652 non-null  float64
#  688  CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                       16652 non-null  float64
#  689  CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                      16652 non-null  float64
#  690  CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                       16652 non-null  float64
#  691  CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                       16592 non-null  float64
#  692  CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                        16652 non-null  float64
#  693  CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                        16652 non-null  float64
#  694  CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                       16652 non-null  float64
#  695  CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                        16652 non-null  float64
#  696  CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                        16592 non-null  float64
#  697  CC_AMT_RECIVABLE_MIN                                                   16652 non-null  float64
#  698  CC_AMT_RECIVABLE_MAX                                                   16652 non-null  float64
#  699  CC_AMT_RECIVABLE_MEAN                                                  16652 non-null  float64
#  700  CC_AMT_RECIVABLE_SUM                                                   16652 non-null  float64
#  701  CC_AMT_RECIVABLE_VAR                                                   16592 non-null  float64
#  702  CC_AMT_TOTAL_RECEIVABLE_MIN                                            16652 non-null  float64
#  703  CC_AMT_TOTAL_RECEIVABLE_MAX                                            16652 non-null  float64
#  704  CC_AMT_TOTAL_RECEIVABLE_MEAN                                           16652 non-null  float64
#  705  CC_AMT_TOTAL_RECEIVABLE_SUM                                            16652 non-null  float64
#  706  CC_AMT_TOTAL_RECEIVABLE_VAR                                            16592 non-null  float64
#  707  CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                        11053 non-null  float64
#  708  CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                        11053 non-null  float64
#  709  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                       11053 non-null  float64
#  710  CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                        16652 non-null  float64
#  711  CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                        10998 non-null  float64
#  712  CC_CNT_DRAWINGS_CURRENT_MIN                                            16652 non-null  float64
#  713  CC_CNT_DRAWINGS_CURRENT_MAX                                            16652 non-null  float64
#  714  CC_CNT_DRAWINGS_CURRENT_MEAN                                           16652 non-null  float64
#  715  CC_CNT_DRAWINGS_CURRENT_SUM                                            16652 non-null  float64
#  716  CC_CNT_DRAWINGS_CURRENT_VAR                                            16592 non-null  float64
#  717  CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                      11053 non-null  float64
#  718  CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                      11053 non-null  float64
#  719  CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                     11053 non-null  float64
#  720  CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                      16652 non-null  float64
#  721  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                      10998 non-null  float64
#  722  CC_CNT_DRAWINGS_POS_CURRENT_MIN                                        11053 non-null  float64
#  723  CC_CNT_DRAWINGS_POS_CURRENT_MAX                                        11053 non-null  float64
#  724  CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                       11053 non-null  float64
#  725  CC_CNT_DRAWINGS_POS_CURRENT_SUM                                        16652 non-null  float64
#  726  CC_CNT_DRAWINGS_POS_CURRENT_VAR                                        10998 non-null  float64
#  727  CC_CNT_INSTALMENT_MATURE_CUM_MIN                                       16652 non-null  float64
#  728  CC_CNT_INSTALMENT_MATURE_CUM_MAX                                       16652 non-null  float64
#  729  CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                      16652 non-null  float64
#  730  CC_CNT_INSTALMENT_MATURE_CUM_SUM                                       16652 non-null  float64
#  731  CC_CNT_INSTALMENT_MATURE_CUM_VAR                                       16592 non-null  float64
#  732  CC_SK_DPD_MIN                                                          16652 non-null  float64
#  733  CC_SK_DPD_MAX                                                          16652 non-null  float64
#  734  CC_SK_DPD_MEAN                                                         16652 non-null  float64
#  735  CC_SK_DPD_SUM                                                          16652 non-null  float64
#  736  CC_SK_DPD_VAR                                                          16592 non-null  float64
#  737  CC_SK_DPD_DEF_MIN                                                      16652 non-null  float64
#  738  CC_SK_DPD_DEF_MAX                                                      16652 non-null  float64
#  739  CC_SK_DPD_DEF_MEAN                                                     16652 non-null  float64
#  740  CC_SK_DPD_DEF_SUM                                                      16652 non-null  float64
#  741  CC_SK_DPD_DEF_VAR                                                      16592 non-null  float64
#  742  CC_NAME_CONTRACT_STATUS_Active_MIN                                     16652 non-null  float64
#  743  CC_NAME_CONTRACT_STATUS_Active_MAX                                     16652 non-null  float64
#  744  CC_NAME_CONTRACT_STATUS_Active_MEAN                                    16652 non-null  float64
#  745  CC_NAME_CONTRACT_STATUS_Active_SUM                                     16652 non-null  float64
#  746  CC_NAME_CONTRACT_STATUS_Active_VAR                                     16592 non-null  float64
#  747  CC_NAME_CONTRACT_STATUS_Approved_MIN                                   16652 non-null  float64
#  748  CC_NAME_CONTRACT_STATUS_Approved_MAX                                   16652 non-null  float64
#  749  CC_NAME_CONTRACT_STATUS_Approved_MEAN                                  16652 non-null  float64
#  750  CC_NAME_CONTRACT_STATUS_Approved_SUM                                   16652 non-null  float64
#  751  CC_NAME_CONTRACT_STATUS_Approved_VAR                                   16592 non-null  float64
#  752  CC_NAME_CONTRACT_STATUS_Completed_MIN                                  16652 non-null  float64
#  753  CC_NAME_CONTRACT_STATUS_Completed_MAX                                  16652 non-null  float64
#  754  CC_NAME_CONTRACT_STATUS_Completed_MEAN                                 16652 non-null  float64
#  755  CC_NAME_CONTRACT_STATUS_Completed_SUM                                  16652 non-null  float64
#  756  CC_NAME_CONTRACT_STATUS_Completed_VAR                                  16592 non-null  float64
#  757  CC_NAME_CONTRACT_STATUS_Demand_MIN                                     16652 non-null  float64
#  758  CC_NAME_CONTRACT_STATUS_Demand_MAX                                     16652 non-null  float64
#  759  CC_NAME_CONTRACT_STATUS_Demand_MEAN                                    16652 non-null  float64
#  760  CC_NAME_CONTRACT_STATUS_Demand_SUM                                     16652 non-null  float64
#  761  CC_NAME_CONTRACT_STATUS_Demand_VAR                                     16592 non-null  float64
#  762  CC_NAME_CONTRACT_STATUS_Refused_MIN                                    16652 non-null  float64
#  763  CC_NAME_CONTRACT_STATUS_Refused_MAX                                    16652 non-null  float64
#  764  CC_NAME_CONTRACT_STATUS_Refused_MEAN                                   16652 non-null  float64
#  765  CC_NAME_CONTRACT_STATUS_Refused_SUM                                    16652 non-null  float64
#  766  CC_NAME_CONTRACT_STATUS_Refused_VAR                                    16592 non-null  float64
#  767  CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                              16652 non-null  float64
#  768  CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                              16652 non-null  float64
#  769  CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                             16652 non-null  float64
#  770  CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                              16652 non-null  float64
#  771  CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                              16592 non-null  float64
#  772  CC_NAME_CONTRACT_STATUS_Signed_MIN                                     16652 non-null  float64
#  773  CC_NAME_CONTRACT_STATUS_Signed_MAX                                     16652 non-null  float64
#  774  CC_NAME_CONTRACT_STATUS_Signed_MEAN                                    16652 non-null  float64
#  775  CC_NAME_CONTRACT_STATUS_Signed_SUM                                     16652 non-null  float64
#  776  CC_NAME_CONTRACT_STATUS_Signed_VAR                                     16592 non-null  float64
#  777  CC_COUNT                                                               16652 non-null  float64
# dtypes: float64(735), int64(43)
# memory usage: 289.7 MB

# %%
print("Datastet test V1")
print(data_test.select_dtypes("object").columns)
# Out:
# Datastet test V1
# Index([], dtype='object')

# %% [markdown]
# ## 3. Test du pipeline

# %% [markdown]
# ### 3.1 Définition du pipeline

# %% [markdown]
# Le pipeline doit réaliser plusieurs fonction :
# - Encodage, réaliser lors du feature engineering notebook, data_preprocess
# - Imputation, remplir les NaN du dataframe
# - SMOTE, gestion du déséquilibre de classe : [Guide d'utilisation](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/)
# - Classification, modèle en lui même classe les clients en deux catégorie. Vas rembourser le crédits, ne vas pas rembourser le crédit
# - Optimisation du seuil de décision, le modèle calcul une probabilité qui doit être transformer en classifieur avec un seuil qui peut être optimisé

# %%
'''
Pas besoin d'un transformer dans le pipeline l'encodage est réaliser lors du feature engineering

transformer = ColumnTransformer([ # Encodage des variables type object 
              ("Ordi_encoder", OrdinalEncoder(), tow_class_columns),
              ("one-hot_encoder", OneHotEncoder(sparse_output=False), more_class_columns)
                ])
'''

pipe = Pipeline([
              #("transformer", transformer),
              ("imputer", SimpleImputer(strategy = "median", missing_values = float("nan"))), # Comme le linéar tourne normalement le replace marche
              ("under_SMOTE", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
              ("over_SMOTE", SMOTE(random_state=42)),
              #("pca", PCA()),
              ("Scaler", MinMaxScaler()),
              ("Classifier", RandomForestClassifier()), # Place holder qui seras remplacer lors du grid search
              #("Threshold_tuner", )
                ])

# %% [markdown]
# RandomUnderSampler [lien vers la fiche fonction](https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.RandomUnderSampler.html)

# %%
pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier', RandomForestClassifier())])

# %% [markdown]
# ### 3.2 Définition de la metric

# %%
def my_metric(y_true, y_pred):
    
    cm = confusion_matrix(y_true, y_pred)

    gain_matrix = np.array(
        [
            [0, -1],
            [-10, 0]
        ]
    )
    return np.sum(cm * gain_matrix)
    
my_scorer = make_scorer(my_metric, response_method="predict")

# %% [markdown]
# ### 3.3 Définition du grid search
# Les prochaine run on pour objectif d'optimiser les hyperparamètre du model de HistGradientBoostingClassifier(random_state=42)()

# %%
# Définir un grid search avec plusieurs modèles
param_grid = [
    {
        # ----- Support‑Vector Regressor ---------------------------------------
        #'pca__n_components' : [25],
        "Classifier": [HistGradientBoostingClassifier(random_state=42)],
        "Classifier__learning_rate": [0.02, 0.05, 0.07],
        "Classifier__max_iter" : [250; 300, 400],
        "Classifier__max_depth": [16, 18, 20],
        "Classifier__l2_regularization" : [0, 0.5, 1],
        "Calssifier__max_leaf_nodes" : [20, 31, 50, 70]
    },
]

# Définir la GridSearch avec le scorer
grid_search = GridSearchCV(pipe, param_grid, scoring=my_scorer, n_jobs=1, error_score='raise')

# %% [markdown]
# n = 8 et p = 3, arrangement = 336

# %% [raw]
# 1
# # Définir un grid search avec plusieurs modèles
# param_grid = [
#     {
#         # ----- Support‑Vector Regressor ---------------------------------------
#         #'pca__n_components' : [25],
#         "Classifier": [HistGradientBoostingClassifier(random_state=42)],
#         "Classifier__learning_rate": [0.1, 0.2, 0.5],
#         "Classifier__max_iter" : [100, 200],
#         "Classifier__max_depth": [10, 15],
#     },
# ]
#
# # Définir la GridSearch avec le scorer
# grid_search = GridSearchCV(pipe, param_grid, scoring=my_scorer, n_jobs=5, error_score='raise')

# %% [raw]
# 2
# # Définir un grid search avec plusieurs modèles
# param_grid = [
#     {
#         # ----- Support‑Vector Regressor ---------------------------------------
#         #'pca__n_components' : [25],
#         "Classifier": [HistGradientBoostingClassifier(random_state=42)],
#         "Classifier__learning_rate": [0.05, 0.10],
#         "Classifier__max_iter" : [100, 250],
#         "Classifier__max_depth": [12, 15, 16],
#     },
# ]
#
# # Définir la GridSearch avec le scorer
# grid_search = GridSearchCV(pipe, param_grid, scoring=my_scorer, n_jobs=2, error_score='raise')

# %%
3
# Définir un grid search avec plusieurs modèles
param_grid = [
    {
        # ----- Support‑Vector Regressor ---------------------------------------
        #'pca__n_components' : [25],
        "Classifier": [HistGradientBoostingClassifier(random_state=42)],
        "Classifier__learning_rate": [0.02, 0.05, 0.07],
        "Classifier__max_iter" : [250; 300, 400],
        "Classifier__max_depth": [16, 18, 20],
        "Classifier__l2_regularization" : [0, 0.5, 1],
        "Calssifier__max_leaf_nodes" : [20, 31, 50, 70]
    },
]

# Définir la GridSearch avec le scorer
grid_search = GridSearchCV(pipe, param_grid, scoring=my_scorer, n_jobs=1, error_score='raise')

# %% [markdown]
# ### 3.4 Test gridsearch x pipeline

# %% [markdown]
# Rapel du pipeline actif

# %%
pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier', RandomForestClassifier())])

# %% [markdown]
# Entraîner le pipeline sur un petit échantillon du dataset pour vérifier qu'il s'exécute correctement

# %%
# Sampling
tmp = data.sample(10000, random_state=42)
X_tmp = tmp.loc[: , tmp.columns[2:]]
y_tmp = tmp["TARGET"]

# %%
# Effectuer la recherche
grid_search.fit(X_tmp, y_tmp)
# Out:
# GridSearchCV(error_score='raise',
#              estimator=Pipeline(steps=[('imputer',
#                                         SimpleImputer(strategy='median')),
#                                        ('under_SMOTE',
#                                         RandomUnderSampler(random_state=42)),
#                                        ('over_SMOTE', SMOTE(random_state=42)),
#                                        ('Scaler', MinMaxScaler()),
#                                        ('Classifier',
#                                         RandomForestClassifier())]),
#              n_jobs=5,
#              param_grid=[{'Classifier': [HistGradientBoostingClassifier(random_state=42)],
#                           'Classifier__learning_rate': [0.1, 0.3, 0.5, 1],
#                           'Classifier__max_depth': [5, 10],
#                           'Classifier__max_iter': [100, 200]}],
#              scoring=make_scorer(my_metric, response_method='predict'))

# %%
print("Best estimator :", grid_search.best_estimator_)
print("Best CV score  :", -grid_search.best_score_)   # MSE (positive)
print("Chosen model   :", type(grid_search.best_estimator_.named_steps["Classifier"]).__name__)
# Out:
# Best estimator : Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.3, max_depth=5,
#                                                 random_state=42))])
# Best CV score  : 6488.2
# Chosen model   : HistGradientBoostingClassifier

# %%
# Dummy V1, plusieurs modèle, seuil None
grid_search.best_score_
# Out:
# -6488.2

# %%
test_model = grid_search.best_estimator_

# %%
test_model
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.3, max_depth=5,
#                                                 random_state=42))])

# %%
y_pred = test_model.predict_proba(X_tmp)
y_pred
# Out:
# array([[0.00111531, 0.99888469],
#        [0.20021884, 0.79978116],
#        [0.54537183, 0.45462817],
#        ...,
#        [0.9796258 , 0.0203742 ],
#        [0.96438868, 0.03561132],
#        [0.01480149, 0.98519851]])

# %%
y_pred = y_pred[:,1]
y_pred
# Out:
# array([0.99888469, 0.79978116, 0.45462817, ..., 0.0203742 , 0.03561132,
#        0.98519851])

# %%
y_pred = pd.Series(y_pred, name="y_pred")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 y_pred = pd.Series(y_pred, name="y_pred")
#
# NameError: name 'y_pred' is not defined

# %%
pred_df = pd.concat([y_pred.reset_index(drop=True), y_pred], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pred_df = pd.concat([y_pred.reset_index(drop=True), y_pred], axis=1)
#
# NameError: name 'y_pred' is not defined

# %%
pred_df.loc[:, "pred_label"] = (pred_df["y_pred"] >= threshold).astype(int)

# %% [markdown]
# ## 4. Suivie des entrainement avec mlflow

# %% [markdown]
# ### 4.1 Définition de l'entrainement

# %% [markdown]
# Je vais entraîner plusieurs modèles avec ce notebook en changeant le pipeline définit en dessous et le dataset. Les résultats serons stocker dans la base de données de mlflow.
#
# Plan d'expérience :
# - data : VO, impute : median, Scaler : min-max, model : LogistiqueRegression, treshold : 0.5) "dummy1"
# - data : V1, impute : median, Scaler : min-max, model : LogistiqueRegression, treshold : 0.5) "dummy2"
# - data : V1, impute : median, ACP=True, Scaler : min-max, model : LogistiqueRegression, treshold : 0.5
# - data : V1, impute : median, ACP=True, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, treshold : 0.09
# - data : V1, impute : median, SMOTE(under over), ACP=True, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, treshold : 0.09
# - data : V1, impute : median, SMOTE(under over), ACP=True, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, treshold : 0.5
# - train/test: True, data : V1, impute : median, SMOTE(under over), ACP=True, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, threshold : 0.5
# - train/test: True, threshold= False, data : V1, impute : median, SMOTE(under over), ACP=True, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, threshold=False
# - train/test: True, threshold= False, data : V1, impute : median, SMOTE(under over), ACP=False, Scaler : min-max, model : LogistiqueRegression, RandomForestClassifier, HistGradientBoostedTree, threshold=False
# - test avec nouvelle matrice
# - Nouvelle matrice, ajout d'une random seed pour l'oversampling
# - Réentrainement a cause de changement d'environnement mais comme nouvelle matrice
# - Optimisation des hyperparamètres 1, 2

# %%
pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier', RandomForestClassifier())])

# %%
grid_search
# Out:
# GridSearchCV(error_score='raise',
#              estimator=Pipeline(steps=[('imputer',
#                                         SimpleImputer(strategy='median')),
#                                        ('under_SMOTE',
#                                         RandomUnderSampler(random_state=42)),
#                                        ('over_SMOTE', SMOTE(random_state=42)),
#                                        ('Scaler', MinMaxScaler()),
#                                        ('Classifier',
#                                         RandomForestClassifier())]),
#              n_jobs=2,
#              param_grid=[{'Classifier': [HistGradientBoostingClassifier(random_state=42)],
#                           'Classifier__learning_rate': [0.05, 0.1],
#                           'Classifier__max_depth': [12, 15, 16],
#                           'Classifier__max_iter': [100, 250]}],
#              scoring=make_scorer(my_metric, response_method='predict'))

# %% [markdown]
# ### 4.2 Lancement du suivie

# %% [raw]
# # Pour activer l'interface utilisateur du suivie
#
# # Bash
# cd OneDrive - CNR/Documents/Jupyter/Openclassrooms/Projets Openclassrooms/Projet-7-Implementez-un-modele-de-scoring/data
# mlflow server --port 5000 --backend-store-uri=sqlite://OneDrive - CNR/Documents/Jupyter/Openclassrooms/Projets Openclassrooms/Projet-7-Implementez-un-modele-de-scoring/data/mlflow.db

# %% [markdown]
# [adresse local du serveur de suivie](http://127.0.0.1:5000)

# %%
# Enclencher le suivie avec le bon fichier de base de données
mlflow.set_tracking_uri("sqlite:///data/mlflow.db")
mlflow.sklearn.autolog()
mlflow.set_experiment("Projet 7 Openclassrooms : Implementez un model de scoring")
# Out:
# <Experiment: artifact_location=('file:C:/Users/SUZON/OneDrive - CNR/Documents/Jupyter/Openclassrooms/Projets '
#  'Openclassrooms/Projet-7-Implementez-un-modele-de-scoring/mlruns/4'), creation_time=1770373572030, experiment_id='4', last_update_time=1770373572030, lifecycle_stage='active', name='Projet 7 Openclassrooms : Implementez un model de scoring', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %% [markdown]
# ### 4.3 Lancement de la run

# %% [markdown]
# Rappel du pipeline définit

# %%
pipe
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier', RandomForestClassifier())])

# %% [markdown]
# Entrainement

# %%
with mlflow.start_run(run_name="Optimisation des hyperparamètres 3"):
    
    # Construire un train test split
    X_train, X_test, y_train, y_test = train_test_split(
                                                        data.loc[:, data.columns[2:]], data["TARGET"],
                                                        test_size=0.20,
                                                        random_state=42,
                                                        )
    # Vérifier que les deux set de données produit contiennent bien la classe rare
    print(f"Nombre d'individu dans le split train : {y_train.value_counts(normalize=True)}")
    print(f"Nombre d'individu dans le split train : {y_test.value_counts(normalize=True)}")
    
    # Recherche d'hyper paramètre et entrainement
    grid_search.fit(X_train, y_train)

    # Score sur le set de test
    grid_search.score(X_test, y_test)
# Out:
# Nombre d'individu dans le split train : TARGET
# 0.0    0.919172
# 1.0    0.080828
# Name: proportion, dtype: float64
# Nombre d'individu dans le split train : TARGET
# 0.0    0.919672
# 1.0    0.080328
# Name: proportion, dtype: float64
# 2026/03/09 17:38:18 INFO mlflow.sklearn.utils: Logging the 5 best runs, 7 runs will be omitted.

# %%
print("Best estimator :", grid_search.best_estimator_)
print("Best CV score  :", -grid_search.best_score_)   # MSE (positive)
print("Chosen model   :", type(grid_search.best_estimator_.named_steps["Classifier"]).__name__)
print("Score on test dataset:", -grid_search.score(X_test, y_test))
# Out:
# Best estimator : Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.05,
#                                                 max_depth=16, max_iter=250,
#                                                 random_state=42))])
# Best CV score  : 24692.0
# Chosen model   : HistGradientBoostingClassifier
# Score on test dataset: 30922

# %% [markdown]
# Récupérer le meilleur modèle du gridsearch

# %%
model = grid_search.best_estimator_

# %%
model
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('under_SMOTE', RandomUnderSampler(random_state=42)),
#                 ('over_SMOTE', SMOTE(random_state=42)),
#                 ('Scaler', MinMaxScaler()),
#                 ('Classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.05,
#                                                 max_depth=16, max_iter=250,
#                                                 random_state=42))])

# %% [markdown]
# ### 4.4 Graphique d'évaluation du best modèle
# [Tutoriel issue de scikit learn](https://scikit-learn.org/stable/auto_examples/model_selection/plot_cost_sensitive_learning.html)

# %%
import warnings

# %%
# Ignorer les erreurs de la signature du modèle, problème de NaN dans des colonnes type int
warnings.filterwarnings(
    "ignore",
    message=".*Inferred schema contains integer column.*",
    category=UserWarning,
)

# %%
pos_label = 0
neg_label = 1

def fpr_score(y, y_pred, neg_label, pos_label):
    cm = confusion_matrix(y, y_pred, labels=[neg_label, pos_label])
    tn, fp, _, _ = cm.ravel()
    tnr = tn / (tn + fp)
    return 1 - tnr

# %%
def my_metric(y_true, y_pred):
    
    cm = confusion_matrix(y_true, y_pred)

    gain_matrix = np.array(
        [
            [0, -1],
            [-10, 0]
        ]
    )
    return np.sum(cm * gain_matrix)
    
my_scorer = make_scorer(my_metric, response_method="predict")

# %%
tpr_score = recall_score  # TPR and recall are the same metric

scoring = {
    "precision": make_scorer(precision_score, pos_label=pos_label),
    "recall": make_scorer(recall_score, pos_label=pos_label),
    "fpr": make_scorer(fpr_score, neg_label=neg_label, pos_label=pos_label),
    "tpr": make_scorer(tpr_score, pos_label=pos_label),
}

# %%
from sklearn.metrics import PrecisionRecallDisplay, RocCurveDisplay

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

PrecisionRecallDisplay.from_estimator(
    model, X_test, y_test, ax=axs[0], name="GBDT"
)
axs[0].plot(
    scoring["recall"](model, X_test, y_test),
    scoring["precision"](model, X_test, y_test),
    marker="o",
    markersize=10,
    color="tab:blue",
    label="Default cut-off point at a probability of 0.5",
)
axs[0].set_title("Precision-Recall curve")
axs[0].legend()

RocCurveDisplay.from_estimator(
    model,
    X_test,
    y_test,
    ax=axs[1],
    name="GBDT",
    plot_chance_level=True,
)
axs[1].plot(
    scoring["fpr"](model, X_test, y_test),
    scoring["tpr"](model, X_test, y_test),
    marker="o",
    markersize=10,
    color="tab:blue",
    label="Default cut-off point at a probability of 0.5",
)
axs[1].set_title("ROC curve")
axs[1].legend()
_ = fig.suptitle("Evaluation du meilleurs algorithme")

plt.show()

# %% [markdown]
# La precision-Recal curve présente quoi ?
# Précision = ratio de vrais positif sur ensemble des point prévu comme positifs
# Recal/Rapelle = ration de vrais positif sur l'ensemble des points vrais observé
# Dans notre cas on veux maximiser le rapelle car la capacité du modele à détécter le vrais positif. Ce qui limite le nombre de faux positife qui fon perdre de l'argent a l'entreprise.
#
# AUC aire sous la courbe, capacité du modèle a discriminer entre les classe positive et négative, doit être grand.
# AP average précision, indique que, globalement, la précision reste assez faible quand on essaie de détecter tous les positifs (rappel élevé). Cela reflète souvent une difficulté du modèle à faire un bon compromis entre rappel et précision.
#
# La ROC curve du model est bien supérieur a la diagonal, ce qui implique que le modèle fait mieux que un dummy. La forme de la Roc curve ne donne pas vraiment de possibilité d'optimisation du seuil car elle est lisse et constante.
# AUC aire sous la courbe, capacité du modèle a discriminer entre les classe positive et négative, doit être grand.
# AP average précision, indique que, globalement, la précision reste assez faible quand on essaie de détecter tous les positifs (rappel élevé). Cela reflète souvent une difficulté du modèle à faire un bon compromis entre rappel et précision.

# %% [markdown]
# ### 4.5 Optimisation du seuil de décision

# %%
with mlflow.start_run(run_name="Threshols Optimisation des hyperparamètres 3"):
    tuned_model = TunedThresholdClassifierCV(
        estimator=model,
        scoring=my_scorer,
        store_cv_results=True,  # necessary to inspect all results
        response_method="auto",
    )
    tuned_model.fit(X_train, y_train)

# %%
# Calcul des score absolue
score_train_not_tuned = -my_scorer(model, X_train, y_train)
score_train_tuned = -my_scorer(tuned_model, X_train, y_train)
score_test_not_tuned = -my_scorer(model, X_test, y_test)
score_test_tuned = -my_scorer(tuned_model, X_test, y_test)

scores = [
          [score_train_not_tuned, score_test_not_tuned],
          [score_train_tuned, score_test_tuned]
         ]

# %%
scores = pd.DataFrame(scores, columns=["Entrainement", "Test"], index=["Non optimisé", "Optimisé"])

# Rapporter le score au nombre de clients dans les dataframe, car le score métier dépend de ce nombre
scores_relatif = copy.copy(scores)
scores_relatif.loc[:, "Entrainement"] = scores_relatif.loc[:, "Entrainement"]/X_train.shape[0]
scores_relatif.loc[:, "Test"] = scores_relatif.loc[:, "Test"]/X_test.shape[0]
# Out:
# C:\Users\SUZON\AppData\Local\Temp\ipykernel_16340\2558850455.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.43800561 0.43514371]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   scores_relatif.loc[:, "Entrainement"] = scores_relatif.loc[:, "Entrainement"]/X_train.shape[0]
# C:\Users\SUZON\AppData\Local\Temp\ipykernel_16340\2558850455.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5028131  0.50009756]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   scores_relatif.loc[:, "Test"] = scores_relatif.loc[:, "Test"]/X_test.shape[0]

# %%
print("Rapport de l'optimisation du seuil")
print("")
print(f"Seuil définit après l'optimisation : {round(tuned_model.best_threshold_,2)}")
print("")
print("Score métier pour les différents dataset")
display(scores)
print("Score métier rapportés au nombre d'individus des jeux de données")
display(scores_relatif)
# Out:
# Rapport de l'optimisation du seuil
#
# Seuil définit après l'optimisation : 0.51
#
# Score métier pour les différents dataset
#               Entrainement   Test
# Non optimisé        107745  30922
# Optimisé            107041  30755
# Score métier rapportés au nombre d'individus des jeux de données
#               Entrainement      Test
# Non optimisé      0.438006  0.502813
# Optimisé          0.435144  0.500098

# %% [markdown]
# Etant données que le score métier compte le nombre de faux négatif et de faux positif les multiplie par un coefficient puis les sommes le score absolu dépend du nombre total de clients présent dans le dataset. Ainsi pour pouvoir  comparer entre les données utilise lors de l'entraînement et celle utiliser lors du test (deux jeux de données qui non pas la même taille) il faut diviser le score absolu par le nombre de clients de chaque dataset.
# La dans les deux cas le score est meilleurs sur le jeu de test que d'entraînement normale ces le score sur le test qui est "regarder" par l'optimiseur.
# L'optimisation n'apporte pas une très grande différence de score.

# %%
title = "Comparaison of the cut-off point for the vanilla and tuned GBDT model"
plot_roc_pr_curves(model, tuned_model, title=title)

# %% [markdown]
# La courbe du score métier en fonction du seuil de décision ne présente pas de plateau ce qui indique que le model n'est pas en sur-apprentisage. La différence entre le seuil prédéfinit de sklearn qui est à 0.5 et le seuil déterminer par l'optimiseur est minime. Mais le seuil optimisé est l'apex de la courbe précédente donc celui-ci est unique.

# %% [markdown]
# Matrice de confusion

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
model_dict = {"model": model ,
              "title":"Model sans seuil optimisé"}
tuned_model_dict = {"model" : tuned_model,
                    "title" : "Model avec seuil optimisé"}

fig, axes = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14, 6))

# idx ne sert par dans ce cas je ne me rappel plus pourquoi il est là
for idx, (ax, dico) in enumerate(zip(axes.ravel(),[model_dict, tuned_model_dict])): 
    disp = ConfusionMatrixDisplay.from_estimator(
        dico["model"],
        X_test,
        y_test,
        display_labels=["0 positif","1 négatif"],
        cmap=plt.cm.Blues,
        normalize="true",
        ax=ax
    )
    disp.ax_.set_title(dico["title"])
    
# Ajuster le graphique pour optimié la place utilisée
#fig.subplots_adjust(wspace=0.12, hspace=0.4, left=0.025, right=0.975, bottom=0.2, top=0.88)
# Ajouter le titre
fig.text(
        x=0.5,
        y=0.92,
        s=f"Marice de confusion des modèles sur le jeux de données de test",
        ha="center",
        va="center",
        ma="center",
        fontsize=22
    )
plt.show()

# %% [markdown]
# L'optimisation du seuil fait augmenter le nombre de faux positif, mais comme vue précédemment les scores eux diminue un peut.

# %% [markdown]
# ## 5. Sauver le modèle lancer le déploiment cloud

# %% [markdown]
# J'utilise l'ui de mlflow pour déterminer le meilleurs modèle. Puis je l'ajoute au registre de mlflow en tant que "predict_client_payment". Une fois le nom définit je pourrais charger de nouvelle version du modèle dans ce nom. Ensuite pour différencier les différente version stocker sous ce nom j'ajoute le tag "best" au modèle que je souhaite passer en prod. Cette alias me permet d'utiliser toujours le même code pour charger et déployer le modèle sur git.

# %% [markdown]
# ### 5.1 Charger le model depuis la base de données de mlflow

# %%
client = MlflowClient()

# %%
# Nom du modèle à charger depuis la base de donnée de mlflow
model_name = "predict_client_payment" # Non du modèle dans le registre
model_version_alias = "best" # tag du modèle a exporté

# Récupérer les informations sur le modèle
model_info = client.get_model_version_by_alias(model_name, model_version_alias)
model_tags = model_info.tags
print(model_tags)
# Out:
# 2026/03/05 14:28:22 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/03/05 14:28:22 INFO mlflow.store.db.utils: Updating database tables
# 2026/03/05 14:28:22 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/05 14:28:22 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# {'validation_status': 'pending', 'projet_7': 'model'}

# %%
# Construire l'URI du modèle pour l'appel
model_uri = f"models:/{model_name}@{model_version_alias}"
# Charger le modèle avec l'URI
model = mlflow.sklearn.load_model(model_uri)

# %%
# Résumer de la structure du modèle
print(model)
# Out:
# TunedThresholdClassifierCV(estimator=Pipeline(steps=[('imputer',
#                                                       SimpleImputer(strategy='median')),
#                                                      ('under_SMOTE',
#                                                       RandomUnderSampler(random_state=42)),
#                                                      ('over_SMOTE',
#                                                       SMOTE(random_state=42)),
#                                                      ('Scaler', MinMaxScaler()),
#                                                      ('Classifier',
#                                                       HistGradientBoostingClassifier(max_depth=10,
#                                                                                      random_state=42))]),
#                            scoring=make_scorer(my_metric, response_method='predict'),
#                            store_cv_results=True)

# %% [markdown]
# ### 5.2 Sauver le modèle charger depuis la base de donnée

# %% [markdown]
# Signature d'un modèle
#
# Afin de garantir que les données d'entrée d'un modèle sont conformes à ce qui est attendu, les modèles MLflow peuvent inclure des metadatas décrivant les entrées et sorties :
# - Model Signature - description des entrées et sorties du modèle
# - Model Input Example - exemple d'une entrée valide
#
# La signature du modèle permet de renseigner le nom des colonnes et leurs types afin de vérifier si ils sont similaires lors de la prédiction.
#
# [Documentation, exemple signature](https://mlflow.org/docs/latest/ml/model/signatures/)

# %%
signature = infer_signature(X_train, y_train)
# Out:
# D:\Users\SUZON\AppData\Local\anaconda3\envs\projet_7_python_3_11_14\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(

# %%
# requierement pour le fonctionnement de model
requirements = {
                "name": "projet_7_python_3_11_14",
                "channels": ["conda-forge"],
                "dependencies": [
                    "python=3.3.7",
                    {
                        "pip": [
                            "pandas==2.3.3",
                            "numpy==1.26.4",
                            "mlflow==3.7.0",
                            "imbalanced-learn==0.14.1",
                            "scikit-learn==1.8.0",
                            "cloudpickle==3.1.2",
                            "psutil==7.2.2",
                            "pyarrow==12.0.0",
                        ],
                    },
                ],
            }

# %% [markdown]
# #### 5.2.1 Stoker le model pour le local

# %%
# Stocker le modèle en local
# Nom du modèle pour le stockage
model_directory_name = "best_SMOTE_V2.2" 
# Chemin absolu vers le répertoire local de stockage
local_save_directory_path = r".\data\modeles\"

# Sauver le modèle
mlflow.sklearn.save_model(model, os.path.join(local_save_directory_path, model_directory_name), 
                          signature=signature, pyfunc_predict_fn="predict", 
                          conda_env=requirements)

# %% [markdown]
# #### 5.2.2 Déposer le model dans le dossier de l'application pour déploiment

# %%
# Nom du modèle pour le stockage
app_model_directory_name = "mlflow_to_deploy"
# Stocker le modèle pour déploiement dans l'application
app_save_directory_path = r"./app/mlflow_api/mlflow_to_deploy"

# Remplacer l'ancien modèle avec le nouveau
# !! Supprimer le dossier avant d'exporter a nouveau le modèle
mlflow.sklearn.save_model(model, os.path.join(app_save_directory_path, app_model_directory_name),
                          signature=signature, pyfunc_predict_fn="predict",
                          conda_env=requirements)

# %% [markdown]
# ## 6. Data drift with evidently
# [Site du package](https://docs.evidentlyai.com/introduction)

# %% [markdown]
# ###6.1  Application a mon cas d'usage
# Je doit comparer les dataset :
# - application_train, le dataset d'entraînement : data
# - application_test, le dataset de prod : data_test
#
# Les deux jeux de données on été transformer de la même manière

# %% [markdown]
# ### 6.2 Donner à evidently le type des colonnes du dataset
# Les variable catégoriel on été encoder lors du feature engineering donc il n'y a plus de colonne catégoriel a proprement parler

# %%
schema = DataDefinition(
    numerical_columns=data.iloc[: ,2:].columns.to_list(),
    )

# %% [markdown]
# ### 6.3 Create Evidently Datasets to work with

# %%
eval_data_1 = Dataset.from_pandas(
    pd.DataFrame(data.iloc[: ,2:]),
    data_definition=schema
)

# %%
eval_data_2 = Dataset.from_pandas(
    pd.DataFrame(data_test.iloc[: ,2:]),
    data_definition=schema
)

# %% [markdown]
# Eval_data_2 est la référence contre la quelle on mesure le datadrift

# %% [markdown]
# ### 6.4 Calculer le rapport

# %%
report = Report([
    DataDriftPreset() 
])

my_eval = report.run(eval_data_1, eval_data_2)

# %% [markdown]
# ### 6.5 Exporter le rapport

# %%
# Export report in html
my_eval.save_html("DataDrift_Trin_vs_test.html")
